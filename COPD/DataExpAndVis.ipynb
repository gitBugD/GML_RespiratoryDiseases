# %%
# Définir le chemin de base
BASE_PATH = "/mnt/c/Users/ala78/OneDrive - HESSO/BA5/GML/data-gml-health/Refined/9019"

# Définir le nom du fichier
file_name = "COPD_prevalence_rate.csv"

# %% [markdown]
# # Exploration et Visualisation des Données COPD
#
# Ce notebook explore et visualise les données de prévalence de COPD (taux).

# %% [markdown]
# ## 1. Import des bibliothèques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Configuration
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("✅ Bibliothèques importées avec succès")
# Out:
# ✅ Bibliothèques importées avec succès

# %% [markdown]
# ## 2. Chargement des données

# %%
# Charger le dataset
df = pd.read_csv(f"{BASE_PATH}/{file_name}")

print(f"📊 Dataset chargé: {file_name}")
print(f"Shape: {df.shape[0]} lignes × {df.shape[1]} colonnes")
print(f"\n{'='*70}\n")

# Aperçu des premières lignes
print("Aperçu des données:")
df.head()
# Out:
# 📊 Dataset chargé: COPD_prevalence_rate.csv
# Shape: 4950 lignes × 37 colonnes
#
# ======================================================================
#
# Aperçu des données:
#       Measure Country Name                                Disease Metric  \
# 0  Prevalence    Indonesia  Chronic obstructive pulmonary disease   Rate
# 1  Prevalence    Indonesia  Chronic obstructive pulmonary disease   Rate
# 2  Prevalence    Indonesia  Chronic obstructive pulmonary disease   Rate
# 3  Prevalence    Indonesia  Chronic obstructive pulmonary disease   Rate
# 4  Prevalence    Indonesia  Chronic obstructive pulmonary disease   Rate
#
#    Year        Value Country Code  \
# 0  1990  1193.009546          IDN
# 1  1991  1214.971198          IDN
# 2  1992  1237.655515          IDN
# 3  1993  1260.285392          IDN
# 4  1994  1282.440639          IDN
#
#   Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of population)  \
# 0                                      ..
# 1                                    48.9
# 2                        66.6965637207031
# 3                                   55.43
# 4                                    62.8
#
#   Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  \
# 0                                  0.881619792814537
# 1                                  0.935142133635504
# 2                                  0.960601996980232
# 3                                   1.03387458321859
# 4                                   1.08216654865227
#
#   Compulsory education, duration (years) GDP (current US$)  \
# 0                                     ..  106140727333.636
# 1                                     ..  116621996217.133
# 2                                     ..  128026966579.964
# 3                                     ..  158006700301.533
# 4                                     ..  176892143931.505
#
#   GDP per capita (constant 2015 US$) Gini index  \
# 0                   1470.91822258528       31.1
# 1                   1544.99580894527         ..
# 2                   1617.10954872218         ..
# 3                    1693.1074260189       31.8
# 4                   1790.32729962455         ..
#
#    Life expectancy at birth, total (years)  \
# 0                                   63.249
# 1                                   63.703
# 2                                   64.182
# 3                                   64.851
# 4                                   65.041
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                            64.3
# 1                                            61.7
# 2                                            59.2
# 3                                            56.7
# 4                                            54.2
#
#   People using at least basic sanitation services (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#    Population, total  \
# 0          183501098
# 1          186778238
# 2          190043744
# 3          193305168
# 4          196591828
#
#   Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Renewable electricity output (% of total electricity output)  \
# 0                                   20.9171334986378
# 1                                   20.5570433851098
# 2                                   23.8383157083323
# 3                                   19.7753303964758
# 4                                   15.6567623349819
#
#   Surface area (sq. km)  \
# 0               1910930
# 1               1910930
# 2               1910930
# 3               1910930
# 4               1910930
#
#   Unemployment, total (% of total labor force) (national estimate)  \
# 0                                              2.541
# 1                                              2.617
# 2                                              2.734
# 3                                              2.782
# 4                                              4.366
#
#    CO2 emissions  Coal consumption  Energy use  Electricity use  \
# 0        0.76250           0.01886   461.47875        160.67479
# 1        0.86483           0.01876   477.03467        175.87167
# 2        0.97925           0.02251   489.75967        191.97685
# 3        1.01280           0.02581   534.33477        210.14958
# 4        1.01974           0.02541   524.02186        236.77993
#
#    Raw materials extracted  Oil consumption       u10       v10         d2m  \
# 0                     3.15          0.17457 -0.765423  0.051050  295.129436
# 1                     3.32          0.18197 -0.781578 -0.003648  295.105554
# 2                     3.47          0.19290 -0.914758 -0.006794  295.017049
# 3                     3.62          0.19917 -0.792716  0.004065  295.019718
# 4                     4.04          0.20137 -0.750760  0.035189  295.156707
#
#           t2m        sst            sp         skt         blh  \
# 0  298.236619  34.689355  98372.394784  298.443682  416.995369
# 1  298.272935  34.715805  98371.627798  298.402007  418.597569
# 2  298.411253  34.715102  98329.143011  298.612211  442.807229
# 3  298.281467  34.703017  98375.218106  298.473822  428.757010
# 4  298.136857  34.678756  98382.978591  298.180950  402.532593
#
#    PM2.5 pollution
# 0         29.83680
# 1         29.53306
# 2         29.21366
# 3         28.88323
# 4         28.54637

# %% [markdown]
# ## 3. Informations générales sur le dataset

# %%
# Informations sur les colonnes
print("📋 Informations sur les colonnes:")
print(f"{'='*70}")
df.info()

print(f"\n{'='*70}\n")

# Statistiques de base
print("📊 Statistiques descriptives:")
print(f"{'='*70}")
df.describe()
# Out:
# 📋 Informations sur les colonnes:
# ======================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4950 entries, 0 to 4949
# Data columns (total 37 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Measure                                                                     4950 non-null   object
#  1   Country Name                                                                4950 non-null   object
#  2   Disease                                                                     4950 non-null   object
#  3   Metric                                                                      4950 non-null   object
#  4   Year                                                                        4950 non-null   int64
#  5   Value                                                                       4950 non-null   float64
#  6   Country Code                                                                4950 non-null   object
#  7   Access to clean fuels and technologies for cooking (% of population)        4950 non-null   object
#  8   Access to electricity (% of population)                                     4950 non-null   object
#  9   Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  4950 non-null   object
#  10  Compulsory education, duration (years)                                      4950 non-null   object
#  11  GDP (current US$)                                                           4950 non-null   object
#  12  GDP per capita (constant 2015 US$)                                          4950 non-null   object
#  13  Gini index                                                                  4950 non-null   object
#  14  Life expectancy at birth, total (years)                                     4950 non-null   float64
#  15  Mortality rate, infant (per 1,000 live births)                              4950 non-null   float64
#  16  People using at least basic sanitation services (% of population)           4950 non-null   object
#  17  Population, total                                                           4950 non-null   int64
#  18  Poverty headcount ratio at national poverty lines (% of population)         4950 non-null   object
#  19  Renewable electricity output (% of total electricity output)                4950 non-null   object
#  20  Surface area (sq. km)                                                       4950 non-null   object
#  21  Unemployment, total (% of total labor force) (national estimate)            4950 non-null   object
#  22  CO2 emissions                                                               3409 non-null   float64
#  23  Coal consumption                                                            2109 non-null   float64
#  24  Energy use                                                                  4335 non-null   float64
#  25  Electricity use                                                             4287 non-null   float64
#  26  Raw materials extracted                                                     4274 non-null   float64
#  27  Oil consumption                                                             2310 non-null   float64
#  28  u10                                                                         4192 non-null   float64
#  29  v10                                                                         4192 non-null   float64
#  30  d2m                                                                         4192 non-null   float64
#  31  t2m                                                                         4192 non-null   float64
#  32  sst                                                                         4192 non-null   float64
#  33  sp                                                                          4192 non-null   float64
#  34  skt                                                                         4192 non-null   float64
#  35  blh                                                                         4192 non-null   float64
#  36  PM2.5 pollution                                                             4788 non-null   float64
# dtypes: float64(18), int64(2), object(17)
# memory usage: 1.4+ MB
#
# ======================================================================
#
# 📊 Statistiques descriptives:
# ======================================================================
#               Year        Value  Life expectancy at birth, total (years)  \
# count  4950.000000  4950.000000                              4950.000000
# mean   2005.182424  1908.366343                                68.393090
# std       9.215459  1314.182433                                 9.881176
# min    1990.000000   264.855651                                12.158000
# 25%    1997.000000   922.401119                                61.992000
# 50%    2005.000000  1418.028005                                70.376524
# 75%    2013.000000  2812.402911                                75.897561
# max    2021.000000  6105.886451                                84.560000
#
#        Mortality rate, infant (per 1,000 live births)  Population, total  \
# count                                     4950.000000       4.950000e+03
# mean                                        33.328263       4.174661e+07
# std                                         32.174927       1.436317e+08
# min                                          1.800000       5.259700e+04
# 25%                                          7.600000       3.268232e+06
# 50%                                         21.300000       9.752048e+06
# 75%                                         51.175000       2.907278e+07
# max                                        274.000000       1.414204e+09
#
#        CO2 emissions  Coal consumption    Energy use  Electricity use  \
# count    3409.000000       2109.000000   4335.000000      4287.000000
# mean        6.547089          0.506123   2377.597837      3811.515690
# std         7.080480          0.620419   2830.187030      5292.074871
# min        -1.081270          0.000010      9.727290         5.441590
# 25%         1.092570          0.053460    487.737885       517.459705
# 50%         4.266900          0.268070   1375.883500      2010.895820
# 75%         9.814360          0.730730   3128.885015      5137.431430
# max        55.834760          3.600000  21557.475080     55085.168450
#
#        Raw materials extracted  Oil consumption          u10          v10  \
# count              4274.000000      2310.000000  4192.000000  4192.000000
# mean                 14.791675         1.454188    -1.474235    -0.131565
# std                  15.012023         1.612307     3.717333     1.474648
# min                   0.010000         0.016310    -8.746244    -4.924416
# 25%                   3.960000         0.497758    -5.060843    -0.765824
# 50%                   9.430000         1.014845    -1.032623     0.033966
# 75%                  20.500000         1.796407     1.785420     0.782538
# max                 107.420000        12.891250     6.194550     4.374770
#
#                d2m          t2m          sst             sp          skt  \
# count  4192.000000  4192.000000  4192.000000    4192.000000  4192.000000
# mean    287.013958   291.171406   255.190828  100205.046566   292.046490
# std       8.350138     8.224011    83.894729    3641.308184     8.544626
# min     262.817836   266.934097     0.000000   77545.179129   265.577831
# 25%     280.088668   283.715253   279.468610  100890.727794   284.167101
# 50%     288.605544   293.183834   292.107123  101184.435087   294.548497
# 75%     294.910943   298.805417   299.272915  101631.865166   299.884526
# max     297.346425   300.828934   302.968018  102441.999697   302.759796
#
#                blh  PM2.5 pollution
# count  4192.000000      4788.000000
# mean    769.170117        28.294335
# std     127.926309        16.540424
# min     285.577018         4.895180
# 25%     706.631947        17.282050
# 50%     796.828062        23.958525
# 75%     855.845687        34.223392
# max    1028.024176       107.144670

# %%
# Dimensions temporelles et géographiques
print("🌍 Couverture géographique et temporelle:")
print(f"{'='*70}")
print(f"Nombre de pays: {df['Country Name'].nunique()}")
print(f"Nombre d'années: {df['Year'].nunique()}")
print(f"Période: {df['Year'].min()} - {df['Year'].max()}")
print(f"\nDiseases: {df['Disease'].unique()}")
print(f"Measures: {df['Measure'].unique()}")
print(f"Metrics: {df['Metric'].unique()}")
# Out:
# 🌍 Couverture géographique et temporelle:
# ======================================================================
# Nombre de pays: 164
# Nombre d'années: 32
# Période: 1990 - 2021
#
# Diseases: ['Chronic obstructive pulmonary disease']
# Measures: ['Prevalence']
# Metrics: ['Rate']

# %%
# Nombre de valeurs uniques par colonne
unique_counts = df.nunique(dropna=True)
unique_pct = (unique_counts / len(df)) * 100

unique_df = pd.DataFrame({
    'Colonne': unique_counts.index,
    'Valeurs_uniques': unique_counts.values,
    'Pourcentage_du_jeu_de_donnees': unique_pct.values
}).sort_values('Valeurs_uniques', ascending=False).reset_index(drop=True)

print("🔢 Nombre de valeurs uniques par colonne:")
print("-" * 70)
display(unique_df)

# Résumé rapide
single_value_cols = unique_df[unique_df['Valeurs_uniques'] == 1]['Colonne'].tolist()
print(f"\n📌 Colonnes avec une seule valeur unique ({len(single_value_cols)}): {single_value_cols}")

# Visualisation (Top 20 colonnes par nombre de valeurs uniques)
top_n = 20
plt.figure(figsize=(12, 8))
sns.barplot(x='Valeurs_uniques', y='Colonne', data=unique_df.head(top_n), palette='viridis')
plt.title(f'Top {top_n} colonnes par nombre de valeurs uniques', fontsize=14, fontweight='bold')
plt.xlabel('Nombre de valeurs uniques')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# 🔢 Nombre de valeurs uniques par colonne:
# ----------------------------------------------------------------------
#                                               Colonne  Valeurs_uniques  \
# 0                                               Value             4950
# 1                                   Population, total             4948
# 2                                   GDP (current US$)             4835
# 3                  GDP per capita (constant 2015 US$)             4804
# 4   Carbon dioxide (CO2) emissions excluding LULUC...             4791
# 5                                     PM2.5 pollution             4787
# 6             Life expectancy at birth, total (years)             4634
# 7                                          Energy use             4335
# 8                                     Electricity use             4286
# 9                                                 u10             4192
# 10                                                skt             4192
# 11                                                t2m             4192
# 12                                                d2m             4192
# 13                                                 sp             4192
# 14                                                v10             4192
# 15                                                blh             4192
# 16  Renewable electricity output (% of total elect...             4167
# 17                                                sst             4033
# 18                                      CO2 emissions             3408
# 19  People using at least basic sanitation service...             3166
# 20  Unemployment, total (% of total labor force) (...             2511
# 21                            Raw materials extracted             2364
# 22                                    Oil consumption             2301
# 23                                   Coal consumption             2037
# 24            Access to electricity (% of population)             1154
# 25     Mortality rate, infant (per 1,000 live births)             1080
# 26  Access to clean fuels and technologies for coo...              797
# 27                              Surface area (sq. km)              433
# 28  Poverty headcount ratio at national poverty li...              381
# 29                                         Gini index              357
# 30                                       Country Name              164
# 31                                       Country Code              164
# 32                                               Year               32
# 33             Compulsory education, duration (years)               15
# 34                                             Metric                1
# 35                                            Measure                1
# 36                                            Disease                1
#
#     Pourcentage_du_jeu_de_donnees
# 0                      100.000000
# 1                       99.959596
# 2                       97.676768
# 3                       97.050505
# 4                       96.787879
# 5                       96.707071
# 6                       93.616162
# 7                       87.575758
# 8                       86.585859
# 9                       84.686869
# 10                      84.686869
# 11                      84.686869
# 12                      84.686869
# 13                      84.686869
# 14                      84.686869
# 15                      84.686869
# 16                      84.181818
# 17                      81.474747
# 18                      68.848485
# 19                      63.959596
# 20                      50.727273
# 21                      47.757576
# 22                      46.484848
# 23                      41.151515
# 24                      23.313131
# 25                      21.818182
# 26                      16.101010
# 27                       8.747475
# 28                       7.696970
# 29                       7.212121
# 30                       3.313131
# 31                       3.313131
# 32                       0.646465
# 33                       0.303030
# 34                       0.020202
# 35                       0.020202
# 36                       0.020202
# 📌 Colonnes avec une seule valeur unique (3): ['Metric', 'Measure', 'Disease']

# %% [markdown]
# ## 4. Analyse des valeurs manquantes

# %%
# Analyse des valeurs manquantes
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Colonne': missing.index,
    'Valeurs manquantes': missing.values,
    'Pourcentage': missing_pct.values
})

# Filtrer uniquement les colonnes avec des valeurs manquantes
missing_df = missing_df[missing_df['Valeurs manquantes'] > 0].sort_values('Pourcentage', ascending=False)

print("⚠️ Valeurs manquantes par colonne:")
print(f"{'='*70}")
if len(missing_df) > 0:
    print(missing_df.to_string(index=False))
    print(f"\n📊 Total de valeurs manquantes: {df.isnull().sum().sum()}")
else:
    print("✅ Aucune valeur manquante détectée!")
# Out:
# ⚠️ Valeurs manquantes par colonne:
# ======================================================================
#                 Colonne  Valeurs manquantes  Pourcentage
#        Coal consumption                2841    57.393939
#         Oil consumption                2640    53.333333
#           CO2 emissions                1541    31.131313
#                     u10                 758    15.313131
#                     t2m                 758    15.313131
#                     d2m                 758    15.313131
#                     v10                 758    15.313131
#                      sp                 758    15.313131
#                     skt                 758    15.313131
#                     blh                 758    15.313131
#                     sst                 758    15.313131
# Raw materials extracted                 676    13.656566
#         Electricity use                 663    13.393939
#              Energy use                 615    12.424242
#         PM2.5 pollution                 162     3.272727
#
# 📊 Total de valeurs manquantes: 15202

# %%
# Visualisation des valeurs manquantes
if len(missing_df) > 0:
    top_missing = missing_df.head(15)
    
    plt.figure(figsize=(14, 6))
    plt.barh(top_missing['Colonne'], top_missing['Pourcentage'], color='coral')
    plt.xlabel('Pourcentage de valeurs manquantes (%)', fontsize=12)
    plt.title('Top 15 colonnes avec valeurs manquantes', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("✅ Pas de visualisation nécessaire (aucune valeur manquante)")

# %% [markdown]
# ## 5. Distribution de la variable cible (Value)

# %%
# Statistiques sur la variable cible
print("📊 Statistiques de la variable 'Value':")
print(f"{'='*70}")
print(f"Moyenne: {df['Value'].mean():.4f}")
print(f"Médiane: {df['Value'].median():.4f}")
print(f"Écart-type: {df['Value'].std():.4f}")
print(f"Min: {df['Value'].min():.4f}")
print(f"Max: {df['Value'].max():.4f}")
print(f"Quartile 25%: {df['Value'].quantile(0.25):.4f}")
print(f"Quartile 75%: {df['Value'].quantile(0.75):.4f}")

# Distribution
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Histogramme
axes[0].hist(df['Value'].dropna(), bins=50, edgecolor='black', alpha=0.7, color='steelblue')
axes[0].axvline(df['Value'].mean(), color='red', linestyle='--', linewidth=2, label=f'Moyenne: {df["Value"].mean():.2f}')
axes[0].axvline(df['Value'].median(), color='green', linestyle='--', linewidth=2, label=f'Médiane: {df["Value"].median():.2f}')
axes[0].set_xlabel('Value', fontsize=11)
axes[0].set_ylabel('Fréquence', fontsize=11)
axes[0].set_title('Distribution de Value (Histogramme)', fontsize=12, fontweight='bold')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Box plot
axes[1].boxplot(df['Value'].dropna(), vert=True)
axes[1].set_ylabel('Value', fontsize=11)
axes[1].set_title('Distribution de Value (Box Plot)', fontsize=12, fontweight='bold')
axes[1].grid(alpha=0.3)

# Violin plot
axes[2].violinplot([df['Value'].dropna()], vert=True, showmeans=True, showmedians=True)
axes[2].set_ylabel('Value', fontsize=11)
axes[2].set_title('Distribution de Value (Violin Plot)', fontsize=12, fontweight='bold')
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 📊 Statistiques de la variable 'Value':
# ======================================================================
# Moyenne: 1908.3663
# Médiane: 1418.0280
# Écart-type: 1314.1824
# Min: 264.8557
# Max: 6105.8865
# Quartile 25%: 922.4011
# Quartile 75%: 2812.4029

# %% [markdown]
# ## 6. Évolution temporelle

# %%
# Évolution temporelle globale (moyenne par année)
yearly_stats = df.groupby('Year')['Value'].agg(['mean', 'median', 'std', 'count']).reset_index()

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Graphique 1: Moyenne et médiane
axes[0].plot(yearly_stats['Year'], yearly_stats['mean'], marker='o', linewidth=2.5, 
             markersize=7, label='Moyenne', color='steelblue')
axes[0].plot(yearly_stats['Year'], yearly_stats['median'], marker='s', linewidth=2.5, 
             markersize=7, label='Médiane', color='coral')
axes[0].fill_between(yearly_stats['Year'], 
                      yearly_stats['mean'] - yearly_stats['std'],
                      yearly_stats['mean'] + yearly_stats['std'],
                      alpha=0.2, color='steelblue', label='±1 écart-type')
axes[0].set_xlabel('Année', fontsize=12)
axes[0].set_ylabel('Value', fontsize=12)
axes[0].set_title('Évolution temporelle globale de COPD (Moyenne ± Écart-type)', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=10)
axes[0].grid(alpha=0.3)

# Graphique 2: Nombre d'observations
axes[1].bar(yearly_stats['Year'], yearly_stats['count'], color='lightgreen', edgecolor='black', alpha=0.7)
axes[1].set_xlabel('Année', fontsize=12)
axes[1].set_ylabel('Nombre d\'observations', fontsize=12)
axes[1].set_title('Nombre d\'observations par année', fontsize=14, fontweight='bold')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Analyse de la tendance
trend_change = yearly_stats['mean'].iloc[-1] - yearly_stats['mean'].iloc[0]
trend_pct = (trend_change / yearly_stats['mean'].iloc[0]) * 100

print(f"📈 Analyse de la tendance:")
print(f"{'='*70}")
print(f"Valeur initiale ({yearly_stats['Year'].iloc[0]}): {yearly_stats['mean'].iloc[0]:.4f}")
print(f"Valeur finale ({yearly_stats['Year'].iloc[-1]}): {yearly_stats['mean'].iloc[-1]:.4f}")
print(f"Changement: {trend_change:.4f} ({trend_pct:+.2f}%)")
if trend_change > 0:
    print("➡️ Tendance: AUGMENTATION")
else:
    print("➡️ Tendance: DIMINUTION")
# Out:
# 📈 Analyse de la tendance:
# ======================================================================
# Valeur initiale (1990): 1584.3889
# Valeur finale (2021): 2204.5440
# Changement: 620.1551 (+39.14%)
# ➡️ Tendance: AUGMENTATION

# %%
# Afficher les pays avec des observations en 2011
countries_2011 = df[df['Year'] == 2011]['Country Name'].unique()

print("🌍 Pays avec observations en 2011:")
print(f"{'='*70}")
print(f"Nombre de pays: {len(countries_2011)}")
print(f"\nListe des pays:")
for i, country in enumerate(countries_2011, 1):
    print(f"{i}. {country}")
# Out:
# 🌍 Pays avec observations en 2011:
# ======================================================================
# Nombre de pays: 149
#
# Liste des pays:
# 1. Indonesia
# 2. China
# 3. Cambodia
# 4. Democratic People's Republic of Korea
# 5. Lao People's Democratic Republic
# 6. Malaysia
# 7. Viet Nam
# 8. Myanmar
# 9. Philippines
# 10. Thailand
# 11. Timor-Leste
# 12. Fiji
# 13. Papua New Guinea
# 14. Sri Lanka
# 15. Czechia
# 16. Solomon Islands
# 17. United States of America
# 18. Armenia
# 19. Azerbaijan
# 20. North Macedonia
# 21. Hungary
# 22. Vanuatu
# 23. Tajikistan
# 24. Turkmenistan
# 25. Albania
# 26. Kyrgyzstan
# 27. Bulgaria
# 28. Poland
# 29. Georgia
# 30. Kazakhstan
# 31. Mongolia
# 32. Uzbekistan
# 33. Japan
# 34. Bosnia and Herzegovina
# 35. Croatia
# 36. Australia
# 37. Montenegro
# 38. Serbia
# 39. Finland
# 40. Slovakia
# 41. Slovenia
# 42. New Zealand
# 43. Austria
# 44. Belgium
# 45. Romania
# 46. Belarus
# 47. Andorra
# 48. Lithuania
# 49. Latvia
# 50. Brunei Darussalam
# 51. Singapore
# 52. Republic of Moldova
# 53. Estonia
# 54. Russian Federation
# 55. Ukraine
# 56. Republic of Korea
# 57. Cyprus
# 58. Denmark
# 59. Iceland
# 60. Israel
# 61. Italy
# 62. France
# 63. Germany
# 64. Greece
# 65. Ireland
# 66. Netherlands
# 67. Sweden
# 68. Luxembourg
# 69. Norway
# 70. Spain
# 71. Switzerland
# 72. United Kingdom
# 73. Argentina
# 74. Chile
# 75. Canada
# 76. Portugal
# 77. Trinidad and Tobago
# 78. Bolivia (Plurinational State of)
# 79. Colombia
# 80. Ecuador
# 81. Central African Republic
# 82. Angola
# 83. Venezuela (Bolivarian Republic of)
# 84. Mexico
# 85. Congo
# 86. Democratic Republic of the Congo
# 87. Gabon
# 88. Equatorial Guinea
# 89. Burundi
# 90. Comoros
# 91. Brazil
# 92. Djibouti
# 93. Eritrea
# 94. Malawi
# 95. Mozambique
# 96. Libya
# 97. Rwanda
# 98. Somalia
# 99. United Republic of Tanzania
# 100. Uganda
# 101. South Africa
# 102. Morocco
# 103. Algeria
# 104. Iran (Islamic Republic of)
# 105. Qatar
# 106. Oman
# 107. Palestine
# 108. Saudi Arabia
# 109. Mali
# 110. Syrian Arab Republic
# 111. Tunisia
# 112. Niger
# 113. Türkiye
# 114. United Arab Emirates
# 115. Yemen
# 116. Bangladesh
# 117. India
# 118. Bhutan
# 119. Nepal
# 120. Pakistan
# 121. Iraq
# 122. Afghanistan
# 123. Lesotho
# 124. Ethiopia
# 125. Kenya
# 126. Zambia
# 127. Mauritius
# 128. Namibia
# 129. Nigeria
# 130. Madagascar
# 131. Benin
# 132. Burkina Faso
# 133. Ghana
# 134. Peru
# 135. Eswatini
# 136. Zimbabwe
# 137. Cameroon
# 138. Seychelles
# 139. Botswana
# 140. Sao Tome and Principe
# 141. Chad
# 142. Lebanon
# 143. Togo
# 144. Kuwait
# 145. Jordan
# 146. South Sudan
# 147. Egypt
# 148. Bahrain
# 149. Sudan

# %% [markdown]
# ## 7. Analyse géographique (Top/Bottom pays)

# %%
# Calculer la moyenne par pays
country_avg = df.groupby('Country Name')['Value'].mean().sort_values(ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Top 15 pays (valeurs les plus élevées)
top_15 = country_avg.head(15)
axes[0].barh(range(len(top_15)), top_15.values, color='darkred', edgecolor='black')
axes[0].set_yticks(range(len(top_15)))
axes[0].set_yticklabels(top_15.index, fontsize=10)
axes[0].set_xlabel('Valeur moyenne', fontsize=12)
axes[0].set_title('Top 15 pays - Valeurs les plus élevées', fontsize=13, fontweight='bold')
axes[0].invert_yaxis()
axes[0].grid(axis='x', alpha=0.3)

# Bottom 15 pays (valeurs les plus faibles)
bottom_15 = country_avg.tail(15).sort_values(ascending=True)
axes[1].barh(range(len(bottom_15)), bottom_15.values, color='darkgreen', edgecolor='black')
axes[1].set_yticks(range(len(bottom_15)))
axes[1].set_yticklabels(bottom_15.index, fontsize=10)
axes[1].set_xlabel('Valeur moyenne', fontsize=12)
axes[1].set_title('Bottom 15 pays - Valeurs les plus faibles', fontsize=13, fontweight='bold')
axes[1].invert_yaxis()
axes[1].grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"🌍 Résumé géographique:")
print(f"{'='*70}")
print(f"Pays avec valeur la plus élevée: {country_avg.index[0]} ({country_avg.iloc[0]:.4f})")
print(f"Pays avec valeur la plus faible: {country_avg.index[-1]} ({country_avg.iloc[-1]:.4f})")
print(f"Ratio max/min: {country_avg.iloc[0] / country_avg.iloc[-1]:.2f}x")
# Out:
# 🌍 Résumé géographique:
# ======================================================================
# Pays avec valeur la plus élevée: United Kingdom (5481.9954)
# Pays avec valeur la plus faible: Ethiopia (296.9336)
# Ratio max/min: 18.46x

# %% [markdown]
# ## 8. Évolution par pays (Top 5)

# %%
# Évolution temporelle des top 5 pays
top_10_countries = country_avg.head(5).index

plt.figure(figsize=(14, 8))

for country in top_10_countries:
    country_data = df[df['Country Name'] == country].sort_values('Year')
    plt.plot(country_data['Year'], country_data['Value'], 
             marker='o', linewidth=2, markersize=5, label=country, alpha=0.8)

plt.xlabel('Année', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.title('Évolution temporelle - Top 5 pays avec valeurs les plus élevées', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Analyse des corrélations (Features numériques)

# %%
# Identifier les colonnes numériques
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Retirer les colonnes d'identification
id_cols = ['Year']
feature_cols = [col for col in numeric_cols if col not in id_cols]

print(f"📊 Colonnes numériques à analyser: {len(feature_cols)}")

# Calculer les corrélations avec Value
if 'Value' in feature_cols:
    correlations = df[feature_cols].corr()['Value'].drop('Value').abs().sort_values(ascending=False)
    
    # Top 15 corrélations
    top_15_corr = correlations.head(15)
    
    print(f"\n🔗 Top 15 features corrélées avec 'Value':")
    print(f"{'='*70}")
    for feat, corr in top_15_corr.items():
        print(f"{feat[:50]:50s} : {corr:.4f}")
    
    # Visualisation
    plt.figure(figsize=(12, 8))
    plt.barh(range(len(top_15_corr)), top_15_corr.values, color='teal', edgecolor='black')
    plt.yticks(range(len(top_15_corr)), [f[:40] for f in top_15_corr.index], fontsize=10)
    plt.xlabel('Corrélation absolue avec Value', fontsize=12)
    plt.title('Top 15 Features - Corrélation avec Value', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Colonne 'Value' non trouvée dans les données numériques")
# Out:
# 📊 Colonnes numériques à analyser: 19
#
# 🔗 Top 15 features corrélées avec 'Value':
# ======================================================================
# u10                                                : 0.7356
# t2m                                                : 0.7353
# skt                                                : 0.7307
# Life expectancy at birth, total (years)            : 0.6842
# d2m                                                : 0.6703
# Mortality rate, infant (per 1,000 live births)     : 0.6224
# Electricity use                                    : 0.4946
# Raw materials extracted                            : 0.4461
# PM2.5 pollution                                    : 0.4352
# CO2 emissions                                      : 0.3725
# v10                                                : 0.3535
# Energy use                                         : 0.3238
# Coal consumption                                   : 0.2422
# blh                                                : 0.1416
# Population, total                                  : 0.0764

# %%
# Matrice de corrélation pour top features
if 'Value' in feature_cols and len(top_15_corr) > 0:
    # Sélectionner top features + Value
    selected_features = list(top_15_corr.head(10).index) + ['Value']
    
    # Calculer matrice de corrélation
    corr_matrix = df[selected_features].corr()
    
    # Heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
                square=True, linewidths=0.5, cbar_kws={"shrink": 0.8},
                xticklabels=[f[:30] for f in corr_matrix.columns],
                yticklabels=[f[:30] for f in corr_matrix.index])
    plt.title('Matrice de corrélation - Top 10 Features vs Value', fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(fontsize=9)
    plt.tight_layout()
    plt.show()

# %%
seuil = 0.8

# Afficher les couples de variables avec corrélation absolue > seuil
corr = df[numeric_cols].corr()  # utilise numeric_cols défini précédemment
corr_abs = corr.abs()

# Masque pour ne garder que la triangle supérieure (éviter doublons et diagonale)
mask = np.triu(np.ones(corr.shape), k=1).astype(bool)
high = corr_abs.where(mask)

# Construire la liste des paires et trier
high_pairs = high.stack().reset_index()
high_pairs.columns = ['var1', 'var2', 'abs_corr']
high_pairs = high_pairs[high_pairs['abs_corr'] > seuil].sort_values('abs_corr', ascending=False)

if high_pairs.empty:
    print(f"Aucun couple de variables avec corrélation absolue > {seuil} trouvé.")
else:
    print(f"Couples de variables avec corrélation absolue > {seuil} :\n")
    for _, row in high_pairs.iterrows():
        v1, v2, a = row['var1'], row['var2'], row['abs_corr']
        actual = corr.loc[v1, v2]
        print(f"{v1}  <->  {v2} : corr = {actual:.4f} (abs = {a:.4f})")
# Out:
# Couples de variables avec corrélation absolue > 0.8 :
#
# t2m  <->  skt : corr = 0.9987 (abs = 0.9987)
# d2m  <->  t2m : corr = 0.9782 (abs = 0.9782)
# d2m  <->  skt : corr = 0.9774 (abs = 0.9774)
# Life expectancy at birth, total (years)  <->  Mortality rate, infant (per 1,000 live births) : corr = -0.9286 (abs = 0.9286)
# CO2 emissions  <->  Energy use : corr = 0.8614 (abs = 0.8614)
# Energy use  <->  Electricity use : corr = 0.8399 (abs = 0.8399)
# CO2 emissions  <->  Raw materials extracted : corr = 0.8172 (abs = 0.8172)
# sst  <->  sp : corr = 0.8166 (abs = 0.8166)
# CO2 emissions  <->  Oil consumption : corr = 0.8147 (abs = 0.8147)

# %% [markdown]
# ## 10. Distribution par année (Box plots)

# %%
# Box plots par année
years_list = sorted(df['Year'].unique())

plt.figure(figsize=(16, 6))

# Créer les données pour chaque année
data_by_year = [df[df['Year'] == year]['Value'].dropna().values for year in years_list]

# Box plot
bp = plt.boxplot(data_by_year, labels=years_list, patch_artist=True)

# Colorer les box plots
for patch in bp['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

plt.xlabel('Année', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.title('Distribution de Value par année', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Scatter plots (Value vs Top Features)

# %%
# Scatter plots pour les 6 features les plus corrélées
if 'Value' in feature_cols and len(top_15_corr) > 0:
    top_6_features = top_15_corr.head(6).index
    
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    axes = axes.ravel()
    
    for idx, feature in enumerate(top_6_features):
        # Scatter plot
        axes[idx].scatter(df[feature], df['Value'], alpha=0.5, s=30, color='steelblue', edgecolors='black', linewidth=0.5)
        
        # Ligne de régression
        mask = df[[feature, 'Value']].notna().all(axis=1)
        if mask.sum() > 1:
            z = np.polyfit(df.loc[mask, feature], df.loc[mask, 'Value'], 1)
            p = np.poly1d(z)
            x_line = np.linspace(df[feature].min(), df[feature].max(), 100)
            axes[idx].plot(x_line, p(x_line), "r--", linewidth=2, label='Régression linéaire')
        
        axes[idx].set_xlabel(feature[:40], fontsize=10)
        axes[idx].set_ylabel('Value', fontsize=10)
        axes[idx].set_title(f'Value vs {feature[:30]}\n(corr: {correlations[feature]:.3f})', 
                           fontsize=11, fontweight='bold')
        axes[idx].grid(alpha=0.3)
        axes[idx].legend(fontsize=8)
    
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Pas assez de features pour générer les scatter plots")

# %% [markdown]
# ## 12. Résumé de l'exploration

# %%
print("="*80)
print("📊 RÉSUMÉ DE L'EXPLORATION DES DONNÉES")
print("="*80)

print(f"\n📁 Fichier analysé: {file_name}")
print(f"📏 Dimensions: {df.shape[0]} lignes × {df.shape[1]} colonnes")

print(f"\n🌍 Couverture:")
print(f"   • Pays: {df['Country Name'].nunique()}")
print(f"   • Années: {df['Year'].nunique()} ({df['Year'].min()} - {df['Year'].max()})")

print(f"\n📊 Variable cible (Value):")
print(f"   • Moyenne: {df['Value'].mean():.4f}")
print(f"   • Médiane: {df['Value'].median():.4f}")
print(f"   • Min: {df['Value'].min():.4f}")
print(f"   • Max: {df['Value'].max():.4f}")

print(f"\n⚠️ Qualité des données:")
total_missing = df.isnull().sum().sum()
print(f"   • Valeurs manquantes totales: {total_missing}")
if total_missing > 0:
    print(f"   • Pourcentage: {(total_missing / (df.shape[0] * df.shape[1])) * 100:.2f}%")

if len(country_avg) > 0:
    print(f"\n🏆 Pays extrêmes:")
    print(f"   • Plus élevé: {country_avg.index[0]} ({country_avg.iloc[0]:.4f})")
    print(f"   • Plus faible: {country_avg.index[-1]} ({country_avg.iloc[-1]:.4f})")

if 'Value' in feature_cols and len(top_15_corr) > 0:
    print(f"\n🔗 Top 3 corrélations avec Value:")
    for i, (feat, corr) in enumerate(top_15_corr.head(3).items(), 1):
        print(f"   {i}. {feat[:50]}: {corr:.4f}")

print(f"\n📈 Tendance temporelle:")
if trend_change > 0:
    print(f"   • AUGMENTATION de {trend_pct:+.2f}% sur la période")
else:
    print(f"   • DIMINUTION de {trend_pct:.2f}% sur la période")

print("\n" + "="*80)
print("✅ Exploration terminée!")
print("="*80)
# Out:
# ================================================================================
# 📊 RÉSUMÉ DE L'EXPLORATION DES DONNÉES
# ================================================================================
#
# 📁 Fichier analysé: COPD_prevalence_rate.csv
# 📏 Dimensions: 4950 lignes × 37 colonnes
#
# 🌍 Couverture:
#    • Pays: 164
#    • Années: 32 (1990 - 2021)
#
# 📊 Variable cible (Value):
#    • Moyenne: 1908.3663
#    • Médiane: 1418.0280
#    • Min: 264.8557
#    • Max: 6105.8865
#
# ⚠️ Qualité des données:
#    • Valeurs manquantes totales: 15202
#    • Pourcentage: 8.30%
#
# 🏆 Pays extrêmes:
#    • Plus élevé: United Kingdom (5481.9954)
#    • Plus faible: Ethiopia (296.9336)
#
# 🔗 Top 3 corrélations avec Value:
#    1. u10: 0.7356
#    2. t2m: 0.7353
#    3. skt: 0.7307
#
# 📈 Tendance temporelle:
#    • AUGMENTATION de +39.14% sur la période
#
# ================================================================================
# ✅ Exploration terminée!
# ================================================================================

# %% [markdown]
# ## 13. Enrichissement du dataset

# %%
import data_preparation as dp

# Sauvegarder Y_class et Y_label avant l'imputation


# Définir uniquement les colonnes à EXCLURE
# (Ce sont les métadonnées et les cibles)
cols_to_exclude = [
    'Measure', 
    'Country Name', 
    'Disease', 
    'Metric'
]

# Sélectionner les colonnes pour l'imputation
df_for_imputation = df.drop(columns=cols_to_exclude).copy()

print("\n⏳ Étape 1/2 : Preprocessing (remplacement de '..' et 'nan' par NaN)...")
df_prepared = dp.preprocessing(df_for_imputation)

print("\n⏳ Étape 2/2 : Imputation des valeurs manquantes avec IterativeImputer...")
print("⚠️ Cette étape peut prendre quelques minutes...")
df_imputed = dp.impute_nans(df_prepared)

print("\n✓ Imputation terminée !")
print(f"Nombre de NaN après imputation : {df_imputed.isnull().sum().sum()}")

# Récupérer les index originaux et ajouter Y_class et Y_label
df_imputed.index = df.index


print("\n✓ Données préparées et imputées avec succès !")
print(f"Forme finale : {df_imputed.shape}")
# Out:
# ⏳ Étape 1/2 : Preprocessing (remplacement de '..' et 'nan' par NaN)...
#
# ⏳ Étape 2/2 : Imputation des valeurs manquantes avec IterativeImputer...
# ⚠️ Cette étape peut prendre quelques minutes...
# 📊 Colonnes détectées pour l'imputation : 31 colonnes
#
# ✓ Imputation terminée !
# Nombre de NaN après imputation : 0
#
# ✓ Données préparées et imputées avec succès !
# Forme finale : (4950, 195)

# %%
# 2. Affichage des colonnes
dp.display_columns(df_imputed)
cols_to_scale = ['Surface area (sq. km)', 'CO2 emissions', 'Coal consumption', 'Energy use', 'Electricity use', 
                     'Raw materials extracted', 'Oil consumption']
cols_to_delete = ['GDP (current US$)', 'Population, total', 'd2m', 'skt']
# Out:
# --- Liste des 195 colonnes ---
# • Year
# • Value
# • Access to clean fuels and technologies for cooking (% of population)
# • Access to electricity (% of population)
# • Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# • Compulsory education, duration (years)
# • GDP (current US$)
# • GDP per capita (constant 2015 US$)
# • Gini index
# • Life expectancy at birth, total (years)
# • Mortality rate, infant (per 1,000 live births)
# • People using at least basic sanitation services (% of population)
# • Population, total
# • Poverty headcount ratio at national poverty lines (% of population)
# • Renewable electricity output (% of total electricity output)
# • Surface area (sq. km)
# • Unemployment, total (% of total labor force) (national estimate)
# • CO2 emissions
# • Coal consumption
# • Energy use
# • Electricity use
# • Raw materials extracted
# • Oil consumption
# • u10
# • v10
# • d2m
# • t2m
# • sst
# • sp
# • skt
# • blh
# • PM2.5 pollution
# • Country Code_AGO
# • Country Code_ALB
# • Country Code_AND
# • Country Code_ARE
# • Country Code_ARG
# • Country Code_ARM
# • Country Code_AUS
# • Country Code_AUT
# • Country Code_AZE
# • Country Code_BDI
# • Country Code_BEL
# • Country Code_BEN
# • Country Code_BFA
# • Country Code_BGD
# • Country Code_BGR
# • Country Code_BHR
# • Country Code_BIH
# • Country Code_BLR
# • Country Code_BOL
# • Country Code_BRA
# • Country Code_BRN
# • Country Code_BTN
# • Country Code_BWA
# • Country Code_CAF
# • Country Code_CAN
# • Country Code_CHE
# • Country Code_CHL
# • Country Code_CHN
# • Country Code_CIV
# • Country Code_CMR
# • Country Code_COD
# • Country Code_COG
# • Country Code_COL
# • Country Code_COM
# • Country Code_CRI
# • Country Code_CUB
# • Country Code_CYP
# • Country Code_CZE
# • Country Code_DEU
# • Country Code_DJI
# • Country Code_DNK
# • Country Code_DOM
# • Country Code_DZA
# • Country Code_ECU
# • Country Code_EGY
# • Country Code_ERI
# • Country Code_ESP
# • Country Code_EST
# • Country Code_ETH
# • Country Code_FIN
# • Country Code_FJI
# • Country Code_FRA
# • Country Code_GAB
# • Country Code_GBR
# • Country Code_GEO
# • Country Code_GHA
# • Country Code_GNQ
# • Country Code_GRC
# • Country Code_GTM
# • Country Code_HND
# • Country Code_HRV
# • Country Code_HTI
# • Country Code_HUN
# • Country Code_IDN
# • Country Code_IND
# • Country Code_IRL
# • Country Code_IRN
# • Country Code_IRQ
# • Country Code_ISL
# • Country Code_ISR
# • Country Code_ITA
# • Country Code_JAM
# • Country Code_JOR
# • Country Code_JPN
# • Country Code_KAZ
# • Country Code_KEN
# • Country Code_KGZ
# • Country Code_KHM
# • Country Code_KOR
# • Country Code_KWT
# • Country Code_LAO
# • Country Code_LBN
# • Country Code_LBY
# • Country Code_LKA
# • Country Code_LSO
# • Country Code_LTU
# • Country Code_LUX
# • Country Code_LVA
# • Country Code_MAR
# • Country Code_MDA
# • Country Code_MDG
# • Country Code_MEX
# • Country Code_MKD
# • Country Code_MLI
# • Country Code_MLT
# • Country Code_MMR
# • Country Code_MNE
# • Country Code_MNG
# • Country Code_MOZ
# • Country Code_MUS
# • Country Code_MWI
# • Country Code_MYS
# • Country Code_NAM
# • Country Code_NER
# • Country Code_NGA
# • Country Code_NIC
# • Country Code_NLD
# • Country Code_NOR
# • Country Code_NPL
# • Country Code_NZL
# • Country Code_OMN
# • Country Code_PAK
# • Country Code_PAN
# • Country Code_PER
# • Country Code_PHL
# • Country Code_PNG
# • Country Code_POL
# • Country Code_PRK
# • Country Code_PRT
# • Country Code_PRY
# • Country Code_PSE
# • Country Code_QAT
# • Country Code_ROU
# • Country Code_RUS
# • Country Code_RWA
# • Country Code_SAU
# • Country Code_SDN
# • Country Code_SEN
# • Country Code_SGP
# • Country Code_SLB
# • Country Code_SLV
# • Country Code_SOM
# • Country Code_SRB
# • Country Code_SSD
# • Country Code_STP
# • Country Code_SVK
# • Country Code_SVN
# • Country Code_SWE
# • Country Code_SWZ
# • Country Code_SYC
# • Country Code_SYR
# • Country Code_TCD
# • Country Code_TGO
# • Country Code_THA
# • Country Code_TJK
# • Country Code_TKM
# • Country Code_TLS
# • Country Code_TTO
# • Country Code_TUN
# • Country Code_TUR
# • Country Code_TZA
# • Country Code_UGA
# • Country Code_UKR
# • Country Code_URY
# • Country Code_USA
# • Country Code_UZB
# • Country Code_VEN
# • Country Code_VNM
# • Country Code_VUT
# • Country Code_YEM
# • Country Code_ZAF
# • Country Code_ZMB
# • Country Code_ZWE
# ---------------------------------

# %%
df_per_capita = dp.create_per_capita_features(df_imputed, cols_to_scale)
df_cleaned = dp.remove_columns(df_per_capita, columns_to_drop=cols_to_scale+cols_to_delete)
# Out:
# ✅ 7 colonnes 'per_capita' créées.
# 🗑️ 11 colonnes supprimées : ['Surface area (sq. km)', 'CO2 emissions', 'Coal consumption', 'Energy use', 'Electricity use', 'Raw materials extracted', 'Oil consumption', 'GDP (current US$)', 'Population, total', 'd2m', 'skt']

# %%
df_wt = dp.round_features(df_cleaned, ['t2m', 'sst'])
df_final = dp.process_wind_speed(df_wt)
dp.display_columns(df_final)
# Out:
# ✅ Arrondi effectué sur 2 colonnes à 2 décimales.
# ✅ 'Wind_Speed' calculée. Colonnes 'u10' et 'v10' supprimées.
# --- Liste des 190 colonnes ---
# • Year
# • Value
# • Access to clean fuels and technologies for cooking (% of population)
# • Access to electricity (% of population)
# • Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)
# • Compulsory education, duration (years)
# • GDP per capita (constant 2015 US$)
# • Gini index
# • Life expectancy at birth, total (years)
# • Mortality rate, infant (per 1,000 live births)
# • People using at least basic sanitation services (% of population)
# • Poverty headcount ratio at national poverty lines (% of population)
# • Renewable electricity output (% of total electricity output)
# • Unemployment, total (% of total labor force) (national estimate)
# • t2m
# • sst
# • sp
# • blh
# • PM2.5 pollution
# • Country Code_AGO
# • Country Code_ALB
# • Country Code_AND
# • Country Code_ARE
# • Country Code_ARG
# • Country Code_ARM
# • Country Code_AUS
# • Country Code_AUT
# • Country Code_AZE
# • Country Code_BDI
# • Country Code_BEL
# • Country Code_BEN
# • Country Code_BFA
# • Country Code_BGD
# • Country Code_BGR
# • Country Code_BHR
# • Country Code_BIH
# • Country Code_BLR
# • Country Code_BOL
# • Country Code_BRA
# • Country Code_BRN
# • Country Code_BTN
# • Country Code_BWA
# • Country Code_CAF
# • Country Code_CAN
# • Country Code_CHE
# • Country Code_CHL
# • Country Code_CHN
# • Country Code_CIV
# • Country Code_CMR
# • Country Code_COD
# • Country Code_COG
# • Country Code_COL
# • Country Code_COM
# • Country Code_CRI
# • Country Code_CUB
# • Country Code_CYP
# • Country Code_CZE
# • Country Code_DEU
# • Country Code_DJI
# • Country Code_DNK
# • Country Code_DOM
# • Country Code_DZA
# • Country Code_ECU
# • Country Code_EGY
# • Country Code_ERI
# • Country Code_ESP
# • Country Code_EST
# • Country Code_ETH
# • Country Code_FIN
# • Country Code_FJI
# • Country Code_FRA
# • Country Code_GAB
# • Country Code_GBR
# • Country Code_GEO
# • Country Code_GHA
# • Country Code_GNQ
# • Country Code_GRC
# • Country Code_GTM
# • Country Code_HND
# • Country Code_HRV
# • Country Code_HTI
# • Country Code_HUN
# • Country Code_IDN
# • Country Code_IND
# • Country Code_IRL
# • Country Code_IRN
# • Country Code_IRQ
# • Country Code_ISL
# • Country Code_ISR
# • Country Code_ITA
# • Country Code_JAM
# • Country Code_JOR
# • Country Code_JPN
# • Country Code_KAZ
# • Country Code_KEN
# • Country Code_KGZ
# • Country Code_KHM
# • Country Code_KOR
# • Country Code_KWT
# • Country Code_LAO
# • Country Code_LBN
# • Country Code_LBY
# • Country Code_LKA
# • Country Code_LSO
# • Country Code_LTU
# • Country Code_LUX
# • Country Code_LVA
# • Country Code_MAR
# • Country Code_MDA
# • Country Code_MDG
# • Country Code_MEX
# • Country Code_MKD
# • Country Code_MLI
# • Country Code_MLT
# • Country Code_MMR
# • Country Code_MNE
# • Country Code_MNG
# • Country Code_MOZ
# • Country Code_MUS
# • Country Code_MWI
# • Country Code_MYS
# • Country Code_NAM
# • Country Code_NER
# • Country Code_NGA
# • Country Code_NIC
# • Country Code_NLD
# • Country Code_NOR
# • Country Code_NPL
# • Country Code_NZL
# • Country Code_OMN
# • Country Code_PAK
# • Country Code_PAN
# • Country Code_PER
# • Country Code_PHL
# • Country Code_PNG
# • Country Code_POL
# • Country Code_PRK
# • Country Code_PRT
# • Country Code_PRY
# • Country Code_PSE
# • Country Code_QAT
# • Country Code_ROU
# • Country Code_RUS
# • Country Code_RWA
# • Country Code_SAU
# • Country Code_SDN
# • Country Code_SEN
# • Country Code_SGP
# • Country Code_SLB
# • Country Code_SLV
# • Country Code_SOM
# • Country Code_SRB
# • Country Code_SSD
# • Country Code_STP
# • Country Code_SVK
# • Country Code_SVN
# • Country Code_SWE
# • Country Code_SWZ
# • Country Code_SYC
# • Country Code_SYR
# • Country Code_TCD
# • Country Code_TGO
# • Country Code_THA
# • Country Code_TJK
# • Country Code_TKM
# • Country Code_TLS
# • Country Code_TTO
# • Country Code_TUN
# • Country Code_TUR
# • Country Code_TZA
# • Country Code_UGA
# • Country Code_UKR
# • Country Code_URY
# • Country Code_USA
# • Country Code_UZB
# • Country Code_VEN
# • Country Code_VNM
# • Country Code_VUT
# • Country Code_YEM
# • Country Code_ZAF
# • Country Code_ZMB
# • Country Code_ZWE
# • Surface_area_per_capita
# • CO2_emissions_per_capita
# • Coal_consumption_per_capita
# • Energy_use_per_capita
# • Electricity_use_per_capita
# • Raw_materials_extracted_per_capita
# • Oil_consumption_per_capita
# • Wind_Speed
# ---------------------------------

# %%
# Identifier les colonnes numériques
numeric_cols = df_final.select_dtypes(include=[np.number]).columns.tolist()

# Retirer les colonnes d'identification
id_cols = ['Year']
feature_cols = [col for col in numeric_cols if col not in id_cols]

print(f"📊 Colonnes numériques à analyser: {len(feature_cols)}")

# Calculer les corrélations avec Value
if 'Value' in feature_cols:
    correlations = df_final[feature_cols].corr()['Value'].drop('Value').abs().sort_values(ascending=False)
    
    # Top 15 corrélations
    top_15_corr = correlations.head(15)
    
    print(f"\n🔗 Top 15 features corrélées avec 'Value':")
    print(f"{'='*70}")
    for feat, corr in top_15_corr.items():
        print(f"{feat[:50]:50s} : {corr:.4f}")
    
    # Visualisation
    plt.figure(figsize=(12, 8))
    plt.barh(range(len(top_15_corr)), top_15_corr.values, color='teal', edgecolor='black')
    plt.yticks(range(len(top_15_corr)), [f[:40] for f in top_15_corr.index], fontsize=10)
    plt.xlabel('Corrélation absolue avec Value', fontsize=12)
    plt.title('Top 15 Features - Corrélation avec Value', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Colonne 'Value' non trouvée dans les données numériques")
    
# Matrice de corrélation pour top features
if 'Value' in feature_cols and len(top_15_corr) > 0:
    # Sélectionner top features + Value
    selected_features = list(top_15_corr.head(10).index) + ['Value']
    
    # Calculer matrice de corrélation
    corr_matrix = df_final[selected_features].corr()
    
    # Heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
                square=True, linewidths=0.5, cbar_kws={"shrink": 0.8},
                xticklabels=[f[:30] for f in corr_matrix.columns],
                yticklabels=[f[:30] for f in corr_matrix.index])
    plt.title('Matrice de corrélation - Top 10 Features vs Value', fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(fontsize=9)
    plt.tight_layout()
    plt.show()
# Out:
# 📊 Colonnes numériques à analyser: 189
#
# 🔗 Top 15 features corrélées avec 'Value':
# ======================================================================
# Life expectancy at birth, total (years)            : 0.6842
# t2m                                                : 0.6479
# People using at least basic sanitation services (% : 0.6336
# Mortality rate, infant (per 1,000 live births)     : 0.6224
# GDP per capita (constant 2015 US$)                 : 0.6118
# Access to clean fuels and technologies for cooking : 0.5985
# Access to electricity (% of population)            : 0.5691
# Poverty headcount ratio at national poverty lines  : 0.5449
# Gini index                                         : 0.4779
# PM2.5 pollution                                    : 0.4405
# Compulsory education, duration (years)             : 0.4089
# Wind_Speed                                         : 0.3187
# Carbon dioxide (CO2) emissions excluding LULUCF pe : 0.3116
# Country Code_GBR                                   : 0.2194
# Country Code_AUT                                   : 0.1925

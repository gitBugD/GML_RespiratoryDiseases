# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
from sklearn.model_selection import KFold
from collections import Counter
import math

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent    
sys.path.append(str(project_root.resolve()))   # now Python can find modules there

import data_preparation   # regular import works

# %% [markdown]
# ## Import data and transform

# %%
df_raw = pd.read_csv("../../Data/Refined/9019/asthma_prevalence_rate.csv")
df_raw
# Out:
#          Measure Country Name Disease Metric  Year        Value Country Code  \
# 0     Prevalence        Japan  Asthma   Rate  1990  5082.997034          JPN
# 1     Prevalence        Japan  Asthma   Rate  1991  5092.603580          JPN
# 2     Prevalence        Japan  Asthma   Rate  1992  5091.760356          JPN
# 3     Prevalence        Japan  Asthma   Rate  1993  5081.664145          JPN
# 4     Prevalence        Japan  Asthma   Rate  1994  5064.407124          JPN
# ...          ...          ...     ...    ...   ...          ...          ...
# 4945  Prevalence        Sudan  Asthma   Rate  2017  4825.147679          SDN
# 4946  Prevalence        Sudan  Asthma   Rate  2018  4814.203984          SDN
# 4947  Prevalence        Sudan  Asthma   Rate  2019  4803.510151          SDN
# 4948  Prevalence        Sudan  Asthma   Rate  2020  4800.033188          SDN
# 4949  Prevalence        Sudan  Asthma   Rate  2021  4799.286356          SDN
#
#      Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                    ..
# 1                                                    ..
# 2                                                    ..
# 3                                                    ..
# 4                                                    ..
# ...                                                 ...
# 4945                                               54.1
# 4946                                              56.25
# 4947                                               58.9
# 4948                                                 61
# 4949                                               62.8
#
#      Access to electricity (% of population)  \
# 0                                        100
# 1                                        100
# 2                                        100
# 3                                        100
# 4                                        100
# ...                                      ...
# 4945                                      53
# 4946                                    55.3
# 4947                                    57.6
# 4948                                    59.7
# 4949                                    61.8
#
#      Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  \
# 0                                       9.4496485203842
# 1                                      9.49356587396341
# 2                                      9.49874382157927
# 3                                      9.41083802642014
# 4                                      9.80971896020067
# ...                                                 ...
# 4945                                  0.554132847201123
# 4946                                  0.539979158318373
# 4947                                  0.515394963684055
# 4948                                  0.456248148211711
# 4949                                   0.47880950318352
#
#       ... Oil consumption       u10       v10         d2m         t2m  \
# 0     ...         1.97956  1.741828  1.021044  288.076401  292.252000
# 1     ...         2.00120  2.286313  1.311337  288.337128  292.431930
# 2     ...         2.04296  2.025161  1.717294  288.129279  292.314792
# 3     ...         1.99111  1.625297  1.286398  287.874186  292.176917
# 4     ...         2.10148  2.570448  1.109048  288.097394  292.441165
# ...   ...             ...       ...       ...         ...         ...
# 4945  ...             NaN -6.390120 -2.174717  294.064998  298.129478
# 4946  ...             NaN -6.720369 -1.962978  294.571177  298.391357
# 4947  ...             NaN -6.393558 -1.910857  294.429075  298.369937
# 4948  ...             NaN -7.191453 -2.245633  293.988485  297.929028
# 4949  ...             NaN -7.053620 -2.156252  293.577117  297.504207
#
#              sst             sp         skt         blh PM2.5 pollution
# 0     293.810320  102094.635435  293.628495  885.064589        13.37278
# 1     293.870958  101983.583177  293.695755  892.493795        13.29348
# 2     293.702229  102020.582682  293.530340  909.754829        13.22620
# 3     293.652769  102097.751613  293.474290  902.488291        13.17147
# 4     293.978702  102064.984418  293.796735  911.037764        13.12983
# ...          ...            ...         ...         ...             ...
# 4945  298.260798  101349.605304  299.081299  828.716632        59.81684
# 4946  298.527902  101285.615172  299.362520  809.267977        58.69366
# 4947  298.543588  101300.024220  299.369651  819.350147        51.93562
# 4948  298.007299  101402.090968  298.836881  847.942231        45.83490
# 4949  297.582684  101419.436420  298.412535  835.994885             NaN
#
# [4950 rows x 37 columns]

# %%
df_raw.columns
# Out:
# Index(['Measure', 'Country Name', 'Disease', 'Metric', 'Year', 'Value',
#        'Country Code',
#        'Access to clean fuels and technologies for cooking (% of population)',
#        'Access to electricity (% of population)',
#        'Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
#        'Compulsory education, duration (years)', 'GDP (current US$)',
#        'GDP per capita (constant 2015 US$)', 'Gini index',
#        'Life expectancy at birth, total (years)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'People using at least basic sanitation services (% of population)',
#        'Population, total',
#        'Poverty headcount ratio at national poverty lines (% of population)',
#        'Renewable electricity output (% of total electricity output)',
#        'Surface area (sq. km)',
#        'Unemployment, total (% of total labor force) (national estimate)',
#        'CO2 emissions', 'Coal consumption', 'Energy use', 'Electricity use',
#        'Raw materials extracted', 'Oil consumption', 'u10', 'v10', 'd2m',
#        't2m', 'sst', 'sp', 'skt', 'blh', 'PM2.5 pollution'],
#       dtype='object')

# %%
columns_to_keep = [col for col in df_raw.columns if col not in ['Country Name', 'Measure', 'Metric', 'Disease']]
df_excluded = df_raw[columns_to_keep]

# %%
df_prepared = data_preparation.preprocessing(df_excluded)

# %%
df_imputed = data_preparation.impute_nans(df_prepared)
df_imputed
# Out:
# 📊 Colonnes détectées pour l'imputation : 31 colonnes
# test
# C:\Users\rapso\OneDrive - HESSO\HEIG\GML\GML_RespiratoryDiseases\data_preparation.py:60: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .transform(lambda g: g.ffill().bfill())
#         Year        Value  \
# 3192  1990.0  5036.145645
# 3193  1991.0  5039.093665
# 3194  1992.0  5039.644898
# 3195  1993.0  4930.052845
# 3196  1994.0  4797.861343
# ...      ...          ...
# 4435  2017.0  2711.324736
# 4436  2018.0  2717.755086
# 4437  2019.0  2724.218125
# 4438  2020.0  2731.155434
# 4439  2021.0  2738.519435
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 3192                                                5.5
# 3193                                                5.5
# 3194                                                5.5
# 3195                                                5.5
# 3196                                                5.5
# ...                                                 ...
# 4435                                               30.1
# 4436                                               30.3
# 4437                                               30.3
# 4438                                               30.5
# 4439                                               30.5
#
#       Access to electricity (% of population)  \
# 3192                                      4.4
# 3193                                      4.4
# 3194                                      4.4
# 3195                                      4.4
# 3196                                      4.4
# ...                                       ...
# 4435                                     44.0
# 4436                                     45.4
# 4437                                     46.7
# 4438                                     52.7
# 4439                                     49.0
#
#       Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  \
# 3192                                           0.242594
# 3193                                           0.232619
# 3194                                           0.137051
# 3195                                           0.119439
# 3196                                           0.103700
# ...                                                 ...
# 4435                                           0.714627
# 4436                                           0.816126
# 4437                                           0.731382
# 4438                                           0.584283
# 4439                                           0.672480
#
#       Compulsory education, duration (years)  GDP (current US$)  \
# 3192                                     6.0       3.521418e+09
# 3193                                     6.0       3.521418e+09
# 3194                                     6.0       3.521418e+09
# 3195                                     6.0       3.521418e+09
# 3196                                     6.0       3.521418e+09
# ...                                      ...                ...
# 4435                                     7.0       5.107473e+10
# 4436                                     7.0       3.415606e+10
# 4437                                     7.0       2.571566e+10
# 4438                                     7.0       2.686856e+10
# 4439                                     7.0       2.724051e+10
#
#       GDP per capita (constant 2015 US$)  Gini index  \
# 3192                          308.318270   45.989731
# 3193                          308.318270   45.948539
# 3194                          308.318270   45.480208
# 3195                          308.318270   45.431074
# 3196                          308.318270   46.118523
# ...                                  ...         ...
# 4435                         1422.193460   44.300000
# 4436                         1471.394890   44.300000
# 4437                         1356.838211   50.300000
# 4438                         1230.191557   50.300000
# 4439                         1311.531000   50.300000
#
#       Life expectancy at birth, total (years)  ...  Country Code_URY  \
# 3192                                   45.118  ...               0.0
# 3193                                   45.521  ...               0.0
# 3194                                   46.569  ...               0.0
# 3195                                   51.021  ...               0.0
# 3196                                   50.969  ...               0.0
# ...                                       ...  ...               ...
# 4435                                   60.263  ...               0.0
# 4436                                   60.906  ...               0.0
# 4437                                   61.060  ...               0.0
# 4438                                   61.530  ...               0.0
# 4439                                   60.135  ...               0.0
#
#       Country Code_USA  Country Code_UZB  Country Code_VEN  Country Code_VNM  \
# 3192               0.0               0.0               0.0               0.0
# 3193               0.0               0.0               0.0               0.0
# 3194               0.0               0.0               0.0               0.0
# 3195               0.0               0.0               0.0               0.0
# 3196               0.0               0.0               0.0               0.0
# ...                ...               ...               ...               ...
# 4435               0.0               0.0               0.0               0.0
# 4436               0.0               0.0               0.0               0.0
# 4437               0.0               0.0               0.0               0.0
# 4438               0.0               0.0               0.0               0.0
# 4439               0.0               0.0               0.0               0.0
#
#       Country Code_VUT  Country Code_YEM  Country Code_ZAF  Country Code_ZMB  \
# 3192               0.0               0.0               0.0               0.0
# 3193               0.0               0.0               0.0               0.0
# 3194               0.0               0.0               0.0               0.0
# 3195               0.0               0.0               0.0               0.0
# 3196               0.0               0.0               0.0               0.0
# ...                ...               ...               ...               ...
# 4435               0.0               0.0               0.0               0.0
# 4436               0.0               0.0               0.0               0.0
# 4437               0.0               0.0               0.0               0.0
# 4438               0.0               0.0               0.0               0.0
# 4439               0.0               0.0               0.0               0.0
#
#       Country Code_ZWE
# 3192               0.0
# 3193               0.0
# 3194               0.0
# 3195               0.0
# 3196               0.0
# ...                ...
# 4435               1.0
# 4436               1.0
# 4437               1.0
# 4438               1.0
# 4439               1.0
#
# [4950 rows x 195 columns]

# %% [markdown]
# ## XGBoost Regressor

# %% [markdown]
# HistGradientBoostingRegressor (from sklearn.ensemble) is a tree-based model. Tree-based models split data based on thresholds, not on absolute magnitudes, so scaling does not affect them.
# Therefore we can avoid to normalize our features.

# %%
def country_kfold_splits(countries, k=5, random_state=None):
    """
    Generate train/test splits by countries for K-fold CV.
    Returns a list of tuples: (train_countries, test_countries)
    """
    countries = np.array(countries)
    if random_state is not None:
        np.random.seed(random_state)
    np.random.shuffle(countries)
    
    folds = np.array_split(countries, k)  # split into k roughly equal folds
    
    splits = []
    for i in range(k):
        test_countries = folds[i]
        train_countries = np.hstack([folds[j] for j in range(k) if j != i])
        splits.append((train_countries, test_countries))
    return splits

# %%
def train_test_all_years_per_iteration(df, train_columns, target, excluded_columns, n_iterations):
    countries = df['Country Code'].unique()
    
    # Store metrics for all years
    all_train_mse = {}
    all_train_r2 = {}
    all_test_mse = {}
    all_test_r2 = {}
    
    # feature score counter (across all iterations & all years)
    feature_scores = Counter()

    for i in range(n_iterations):
        print(f"Iteration {i} starts") 
        train_mse_list = []
        train_r2_list = []
        mse_list = []
        r2_list = []

        splits = country_kfold_splits(countries, k=5)

        for j, (train_countries, test_countries) in enumerate(splits):
            print(f"Sub-iteration {j}: Train {len(train_countries)} countries, Test {len(test_countries)} countries")
            
            df_train = df[df["Country Code"].isin(train_countries)]
            df_test = df[df["Country Code"].isin(test_countries)]
            
            # X_train, y_train, X_test, y_test
            features = [c for c in train_columns if c not in excluded_columns]
            X_train = df_train[features]
            y_train = df_train[target]
            X_test = df_test[features]
            y_test = df_test[target]
    
            # Initialize XGBoost regressor
            model = XGBRegressor(
                n_estimators=500,
                learning_rate=0.05,
                max_depth=5,
                subsample=0.8,
                colsample_bytree=0.8,
                random_state=42,
                n_jobs=-1
            )
            
            model.fit(X_train, y_train,
                      eval_set=[(X_test, y_test)],
                      verbose=False)
            
            # Predictions and metrics
            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)
            
            train_mse_list.append(mean_squared_error(y_train, y_train_pred))
            train_r2_list.append(r2_score(y_train, y_train_pred))
            test_mse_list.append(mean_squared_error(y_test, y_test_pred))
            test_r2_list.append(r2_score(y_test, y_test_pred))
    
            importance_dict = model.get_booster().get_score(importance_type='weight')  # or 'gain', 'cover'
            # Convert to pandas Series
            perm_importances = pd.Series(importance_dict).reindex(X_train.columns).fillna(0)
            
            # Take top 5 features of this fold
            top_5 = perm_importances.sort_values(ascending=False).head(5)
            feature_scores.update(top_5.index)
    
        # Store averaged metrics for this iteration
        all_train_mse[i] = np.mean(train_mse_list)
        all_train_r2[i] = np.mean(train_r2_list)
        all_test_mse[i] = np.mean(mse_list)
        all_test_r2[i] = np.mean(r2_list)
            
        print(f"Iteration {i} done\n")   

    # ============================================================
    # PLOT: MSE & R2 per iteration
    # ============================================================
    
    # Prepare data
    mean_train_mse_values = [np.mean(mse_list) for i, mse_list in all_train_mse.items()]
    mean_test_mse_values = [np.mean(mse_list) for i, mse_list in all_test_mse.items()]
    mean_train_r2_values = [np.mean(r2_list) for i, r2_list in all_train_r2.items()]
    mean_test_r2_values = [np.mean(r2_list) for i, r2_list in all_test_r2.items()]
    sorted_iterations = range(n_iterations)
    
    # Create plots
    fig, axs = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
    
    # MSE plot
    axs[0].plot(sorted_iterations, mean_train_mse_values, marker='o', linestyle='--', color='orange', label='Train MSE')
    axs[0].plot(sorted_iterations, mean_test_mse_values, marker='o', linestyle='-', color='orange', label='Test MSE')
    axs[0].set_title('Mean MSE per Year')
    axs[0].set_ylabel('Mean Squared Error')
    axs[0].legend()
    axs[0].grid(True)
    
    # R² plot
    axs[1].plot(sorted_iterations, mean_train_r2_values, marker='s', linestyle='--', color='blue', label='Train R²')
    axs[1].plot(sorted_iterations, mean_test_r2_values, marker='s', linestyle='-', color='blue', label='Test R²')
    axs[1].set_title('Mean R² Score per Year')
    axs[1].set_ylabel('R² Score')
    axs[1].set_xlabel('Iteration')
    axs[1].legend()
    axs[1].grid(True)
    
    # Labels and legend
    plt.tight_layout()
    plt.show()

    global_mean_r2_test = np.mean(mean_test_r2_values)
    print(f"Mean R2 value (test): {global_mean_r2_test}")   
    
    # ============================================================
    #  PLOT: Top 6 Most Important Features Across All Iterations
    # ============================================================

    top6 = feature_scores.most_common(6)
    feat_names = [f for f, s in top6]
    feat_scores = [s for f, s in top6]

    plt.figure(figsize=(10, 4))
    plt.barh(feat_names, feat_scores)
    plt.xlabel("Frequency Appearing in Top 5")
    plt.title("Top 6 Most Important Features (Across All Iterations)")
    plt.gca().invert_yaxis()
    plt.grid(axis='x', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %%
train_test_all_years_per_iteration(df_prepared, df_prepared.columns, "Value", ["Value", "Country Code", "Year"], 10)
# Out:
# Iteration 0 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_test_all_years_per_iteration(df_prepared, df_prepared.columns, "Value", ["Value", "Country Code", "Year"], 10)
#
# Cell In[17], line 47, in train_test_all_years_per_iteration(df, train_columns, target, excluded_columns, n_iterations)
#      35 # Initialize XGBoost regressor
#      36 model = XGBRegressor(
#      37     n_estimators=500,
#      38     learning_rate=0.05,
#    (...)     44     n_jobs=-1
#      45 )
# ---> 47 model.fit(X_train, y_train,
#      48           eval_set=[(X_test, y_test)],
#      49           verbose=False)
#      51 # Predictions and metrics
#      52 y_train_pred = model.predict(X_train)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\sklearn.py:1340, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1337 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1339 evals_result: EvalsLog = {}
# -> 1340 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1341     missing=self.missing,
#    1342     X=X,
#    1343     y=y,
#    1344     group=None,
#    1345     qid=None,
#    1346     sample_weight=sample_weight,
#    1347     base_margin=base_margin,
#    1348     feature_weights=feature_weights,
#    1349     eval_set=eval_set,
#    1350     sample_weight_eval_set=sample_weight_eval_set,
#    1351     base_margin_eval_set=base_margin_eval_set,
#    1352     eval_group=None,
#    1353     eval_qid=None,
#    1354     create_dmatrix=self._create_dmatrix,
#    1355     enable_categorical=self.enable_categorical,
#    1356     feature_types=feature_types,
#    1357 )
#    1359 if callable(self.objective):
#    1360     obj: Optional[Objective] = _objective_decorator(self.objective)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\sklearn.py:701, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     696 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     697 way.
#     698
#     699 """
#     700 # Feature_types contains the optional reference categories from the booster object.
# --> 701 train_dmatrix = create_dmatrix(
#     702     data=X,
#     703     label=y,
#     704     group=group,
#     705     qid=qid,
#     706     weight=sample_weight,
#     707     base_margin=base_margin,
#     708     feature_weights=feature_weights,
#     709     missing=missing,
#     710     enable_categorical=enable_categorical,
#     711     feature_types=feature_types,
#     712     ref=None,
#     713 )
#     715 n_validation = 0 if eval_set is None else len(eval_set)
#     716 if hasattr(train_dmatrix, "get_categories"):
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\sklearn.py:1254, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1252 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1253     try:
# -> 1254         return QuantileDMatrix(
#    1255             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1256         )
#    1257     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1258         pass
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:1768, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1748     if any(
#    1749         info is not None
#    1750         for info in (
#    (...)   1761         )
#    1762     ):
#    1763         raise ValueError(
#    1764             "If data iterator is used as input, data like label should be "
#    1765             "specified as batch argument."
#    1766         )
# -> 1768 self._init(
#    1769     data,
#    1770     ref=ref,
#    1771     label=label,
#    1772     weight=weight,
#    1773     base_margin=base_margin,
#    1774     group=group,
#    1775     qid=qid,
#    1776     label_lower_bound=label_lower_bound,
#    1777     label_upper_bound=label_upper_bound,
#    1778     feature_weights=feature_weights,
#    1779     feature_names=feature_names,
#    1780     feature_types=feature_types,
#    1781     enable_categorical=enable_categorical,
#    1782     max_quantile_blocks=max_quantile_batches,
#    1783 )
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:1832, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1817 config = make_jcargs(
#    1818     nthread=self.nthread,
#    1819     missing=self.missing,
#    1820     max_bin=self.max_bin,
#    1821     max_quantile_blocks=max_quantile_blocks,
#    1822 )
#    1823 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1824     None,
#    1825     it.proxy.handle,
#    (...)   1830     ctypes.byref(handle),
#    1831 )
# -> 1832 it.reraise()
#    1833 # delay check_call to throw intermediate exception first
#    1834 _check_call(ret)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:617, in DataIter.reraise(self)
#     615 exc = self._exception
#     616 self._exception = None
# --> 617 raise exc
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:598, in DataIter._handle_exception(self, fn, dft_ret)
#     595     return dft_ret
#     597 try:
# --> 598     return fn()
#     599 except Exception as e:  # pylint: disable=broad-except
#     600     # Defer the exception in order to return 0 and stop the iteration.
#     601     # Exception inside a ctype callback function has no effect except
#     602     # for printing to stderr (doesn't stop the execution).
#     603     tb = sys.exc_info()[2]
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:685, in DataIter._next_wrapper.<locals>.<lambda>()
#     683     self._temporary_data = None
#     684 # pylint: disable=not-callable
# --> 685 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:1632, in SingleBatchInternalIter.next(self, input_data)
#    1630     return False
#    1631 self.it += 1
# -> 1632 input_data(**self.kwargs)
#    1633 return True
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\core.py:665, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     663     new, feature_names, feature_types = self._temporary_data
#     664 else:
# --> 665     new, feature_names, feature_types = _proxy_transform(
#     666         data,
#     667         feature_names,
#     668         feature_types,
#     669         self._enable_categorical,
#     670     )
#     671 # Stage the data, meta info are copied inside C++ MetaInfo.
#     672 self._temporary_data = (new, feature_names, feature_types)
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:1685, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1683     return df_pa, feature_names, feature_types
#    1684 if _is_pandas_df(data):
# -> 1685     df, feature_names, feature_types = _transform_pandas_df(
#    1686         data, enable_categorical, feature_names, feature_types
#    1687     )
#    1688     return df, feature_names, feature_types
#    1689 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:662, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     659     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#     661 feature_types, ref_categories = get_ref_categories(feature_types)
# --> 662 feature_names, feature_types = pandas_feature_info(
#     663     data, meta, feature_names, feature_types, enable_categorical
#     664 )
#     666 arrays = pandas_transform_data(data)
#     667 return (
#     668     PandasTransformed(arrays, ref_categories=ref_categories),
#     669     feature_names,
#     670     feature_types,
#     671 )
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:409, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407             new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408         except KeyError:
# --> 409             _invalid_dataframe_dtype(data)
#     411 if feature_types is None and meta is None:
#     412     feature_types = new_feature_types
#
# File ~\miniconda3\envs\cours-apv\Lib\site-packages\xgboost\data.py:372, in _invalid_dataframe_dtype(data)
#     370 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     371 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 372 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:Access to clean fuels and technologies for cooking (% of population): object, Access to electricity (% of population): object, Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita): object, Compulsory education, duration (years): object, GDP (current US$): object, GDP per capita (constant 2015 US$): object, Gini index: object, People using at least basic sanitation services (% of population): object, Poverty headcount ratio at national poverty lines (% of population): object, Renewable electricity output (% of total electricity output): object, Surface area (sq. km): object, Unemployment, total (% of total labor force) (national estimate): object

# %%
# training only on environmental factors

train_columns= ['Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)',
       'Renewable electricity output (% of total electricity output)',
       'CO2 emissions', 'Coal consumption', 'Energy use', 'Electricity use',
       'Raw materials extracted', 'Oil consumption', 'PM2.5 pollution']

train_test_all_years_per_iteration(df_prepared, train_columns, "Value", ["Value", "Country Code", "Year"], 10)
# Out:
# Iteration 0 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 0 done
#
# Iteration 1 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 1 done
#
# Iteration 2 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 2 done
#
# Iteration 3 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 3 done
#
# Iteration 4 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 4 done
#
# Iteration 5 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 5 done
#
# Iteration 6 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 6 done
#
# Iteration 7 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 7 done
#
# Iteration 8 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 8 done
#
# Iteration 9 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 9 done
# Mean R2 value (test): -0.032095224832661626

# %% [markdown]
# ## Regression transformation

# %% [markdown]
# Here I try to make the problem easier, by transforming the target value.

# %%
# Log-transform: helps if values vary a lot.
df_prepared['y_log'] = np.log1p(df_prepared['Value'])
train_test_all_years_per_iteration(df_prepared, df_prepared.columns, "y_log", ["y_log", "Value", "Country Code", "Year"], 10)
# Out:
# Iteration 0 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 0 done
#
# Iteration 1 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 1 done
#
# Iteration 2 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 2 done
#
# Iteration 3 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 3 done
#
# Iteration 4 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 4 done
#
# Iteration 5 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 5 done
#
# Iteration 6 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 6 done
#
# Iteration 7 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 7 done
#
# Iteration 8 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 8 done
#
# Iteration 9 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 9 done
# Mean R2 value (test): 0.4284920994672203

# %%
# Relative change / difference: predict change from median value across countries.
df_prepared['y_diff'] = df_prepared['Value'] - df_prepared.groupby('Year')['Value'].transform('median')
train_test_all_years_per_iteration(df_prepared, df_prepared.columns, "y_diff", ["y_diff", "y_log", "Value", "Country Code", "Year"], 10)
# Out:
# Iteration 0 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 0 done
#
# Iteration 1 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 1 done
#
# Iteration 2 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 2 done
#
# Iteration 3 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 3 done
#
# Iteration 4 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 4 done
#
# Iteration 5 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 5 done
#
# Iteration 6 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 6 done
#
# Iteration 7 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 7 done
#
# Iteration 8 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 8 done
#
# Iteration 9 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 9 done
# Mean R2 value (test): 0.3717870251576882

# %%
# Relative change / difference: predict change from previous year value (for the same country)
# Sort by country and year
df_prepared = df_prepared.sort_values(['Country Code', 'Year']).reset_index(drop=True)

# Compute change from previous year per country
df_prepared['y_diff_prev_year'] = df_prepared.groupby('Country Code')['Value'].diff()

# Fill NaN (first year for each country) with 0
df_prepared['y_diff_prev_year'] = df_prepared['y_diff_prev_year'].fillna(0)

train_test_all_years_per_iteration(df_prepared, df_prepared.columns, "y_diff_prev_year", ["y_diff_prev_year", "y_diff", "y_log", "Value", "Country Code", "Year"], 10)
# Out:
# Iteration 0 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 0 done
#
# Iteration 1 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 1 done
#
# Iteration 2 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 2 done
#
# Iteration 3 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 3 done
#
# Iteration 4 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 4 done
#
# Iteration 5 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 5 done
#
# Iteration 6 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 6 done
#
# Iteration 7 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 7 done
#
# Iteration 8 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 8 done
#
# Iteration 9 starts
# Sub-iteration 0: Train 131 countries, Test 33 countries
# Sub-iteration 1: Train 131 countries, Test 33 countries
# Sub-iteration 2: Train 131 countries, Test 33 countries
# Sub-iteration 3: Train 131 countries, Test 33 countries
# Sub-iteration 4: Train 132 countries, Test 32 countries
# Iteration 9 done
# Mean R2 value (test): -0.20636956406485713

# %%
# Définir le chemin de base
BASE_PATH = "../../Data"

# Définir le nom du fichier
file_name = "asthma_prevalence_rate.csv"

disease_name = "Asthma"

# %% [markdown]
# # Exploration et Visualisation des Données Asthma
#
# Ce notebook explore et visualise les données de prévalence de Asthma (taux).

# %% [markdown]
# ## 1. Import des bibliothèques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Configuration
warnings.filterwarnings('ignore')
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("✅ Bibliothèques importées avec succès")
# Out:
# ✅ Bibliothèques importées avec succès

# %% [markdown]
# ## 2. Chargement des données

# %%
# Charger le dataset
df = pd.read_csv(f"{BASE_PATH}/Refined/1021/{file_name}")

print(f"📊 Dataset chargé: {file_name}")
print(f"Shape: {df.shape[0]} lignes × {df.shape[1]} colonnes")
print(f"\n{'='*70}\n")

# Aperçu des premières lignes
print("Aperçu des données:")
df.head()
# Out:
# 📊 Dataset chargé: asthma_prevalence_rate.csv
# Shape: 353 lignes × 38 colonnes
#
# ======================================================================
#
# Aperçu des données:
#       Measure Country Name Disease Metric  Year        Value Country Code  \
# 0  Prevalence        Japan  Asthma   Rate  2014  5192.177057          JPN
# 1  Prevalence        Japan  Asthma   Rate  2015  5206.382139          JPN
# 2  Prevalence        Japan  Asthma   Rate  2016  5222.775846          JPN
# 3  Prevalence        Japan  Asthma   Rate  2017  5259.014818          JPN
# 4  Prevalence        Japan  Asthma   Rate  2018  5302.827203          JPN
#
#   Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                100
# 1                                                100
# 2                                                100
# 3                                                100
# 4                                                100
#
#    Access to electricity (% of population)  \
# 0                                    100.0
# 1                                    100.0
# 2                                    100.0
# 3                                    100.0
# 4                                    100.0
#
#   Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  \
# 0                                   10.0274639366416
# 1                                   9.71691822464823
# 2                                   9.70188627278164
# 3                                   9.59147213558895
# 4                                   9.29901664682086
#
#    Compulsory education, duration (years)  GDP (current US$)  \
# 0                                       9       4.896994e+12
# 1                                       9       4.444931e+12
# 2                                       9       5.003678e+12
# 3                                       9       4.930837e+12
# 4                                       9       5.040881e+12
#
#    GDP per capita (constant 2015 US$) Gini index  \
# 0                        34386.905855       31.3
# 1                        34960.639384       30.7
# 2                        35242.199377       31.8
# 3                        35861.972855       31.8
# 4                        36138.529082       32.9
#
#    Life expectancy at birth, total (years)  \
# 0                                83.587805
# 1                                83.793902
# 2                                83.984878
# 3                                84.099756
# 4                                84.210976
#
#    Mortality rate, infant (per 1,000 live births)  \
# 0                                             2.1
# 1                                             2.0
# 2                                             2.0
# 3                                             1.9
# 4                                             1.9
#
#   People using at least basic sanitation services (% of population)  \
# 0                                   99.9612590545948
# 1                                   99.9583127913471
# 2                                   99.9553665280994
# 3                                   99.9524202648517
# 4                                    99.949474001604
#
#    Population, total  \
# 0          127276000
# 1          127141000
# 2          127076000
# 3          126972000
# 4          126811000
#
#   Poverty headcount ratio at national poverty lines (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Renewable electricity output (% of total electricity output)  \
# 0                                   12.3603682310134
# 1                                   14.1787823169286
# 2                                   14.6993686700037
# 3                                   16.1978928080623
# 4                                   17.0618996868318
#
#    Surface area (sq. km)  \
# 0               377962.0
# 1               377971.0
# 2               377970.0
# 3               377970.0
# 4               377974.0
#
#   Unemployment, total (% of total labor force) (national estimate)  \
# 0                                              3.589
# 1                                              3.385
# 2                                              3.132
# 3                                              2.822
# 4                                              2.467
#
#    Total area (Square Km)  PM10_ConcentrationAvg  PM25_ConcentrationAvg  \
# 0                377962.0                    NaN              14.835200
# 1                377971.0                    NaN                    NaN
# 2                377970.0                    NaN                    NaN
# 3                377970.0                    NaN                    NaN
# 4                377974.0                    NaN              11.471067
#
#    NO2_ConcentrationAvg  Greenhouse gases (Kg CO2-equivalent Per Person)  \
# 0             26.890867                                        10.528200
# 1                   NaN                                        10.239480
# 2                   NaN                                        10.101480
# 3                   NaN                                         9.992245
# 4             19.646400                                         9.639091
#
#    Sulphur oxides (tonnes)  Total sales of agricultural pesticides (tonnes)  \
# 0                      NaN                                         53543.70
# 1                 672.6071                                         54171.10
# 2                 638.3277                                         51006.40
# 3                 596.0964                                         52248.52
# 4                 562.3302                                         52331.77
#
#    Share of population who are daily smokers (Pct population)       u10  \
# 0                                               19.6           2.180324
# 1                                               18.2           2.247194
# 2                                               18.3           1.896303
# 3                                               17.7           2.231108
# 4                                               17.8           2.239119
#
#         v10         d2m         t2m         sst             sp         skt  \
# 0  1.293077  288.367888  292.485756  293.779580  102115.801254  293.610257
# 1  1.573335  288.342591  292.509937  293.900725  102082.760935  293.728914
# 2  1.843566  288.471362  292.607193  293.833551  102084.147374  293.667026
# 3  1.180876  288.519120  292.625293  293.974890  101947.341061  293.809990
# 4  1.458739  288.927352  293.018189  294.475368  102117.550669  294.303794
#
#           blh
# 0  885.832315
# 1  905.719678
# 2  903.834044
# 3  896.601952
# 4  904.800901

# %% [markdown]
# ## 3. Informations générales sur le dataset

# %%
# Informations sur les colonnes
print("📋 Informations sur les colonnes:")
print(f"{'='*70}")
df.info()

print(f"\n{'='*70}\n")

# Statistiques de base
print("📊 Statistiques descriptives:")
print(f"{'='*70}")
df.describe()
# Out:
# 📋 Informations sur les colonnes:
# ======================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 38 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Measure                                                                     353 non-null    object
#  1   Country Name                                                                353 non-null    object
#  2   Disease                                                                     353 non-null    object
#  3   Metric                                                                      353 non-null    object
#  4   Year                                                                        353 non-null    int64
#  5   Value                                                                       353 non-null    float64
#  6   Country Code                                                                353 non-null    object
#  7   Access to clean fuels and technologies for cooking (% of population)        353 non-null    object
#  8   Access to electricity (% of population)                                     353 non-null    float64
#  9   Carbon dioxide (CO2) emissions excluding LULUCF per capita (t CO2e/capita)  353 non-null    object
#  10  Compulsory education, duration (years)                                      353 non-null    int64
#  11  GDP (current US$)                                                           353 non-null    float64
#  12  GDP per capita (constant 2015 US$)                                          353 non-null    float64
#  13  Gini index                                                                  353 non-null    object
#  14  Life expectancy at birth, total (years)                                     353 non-null    float64
#  15  Mortality rate, infant (per 1,000 live births)                              353 non-null    float64
#  16  People using at least basic sanitation services (% of population)           353 non-null    object
#  17  Population, total                                                           353 non-null    int64
#  18  Poverty headcount ratio at national poverty lines (% of population)         353 non-null    object
#  19  Renewable electricity output (% of total electricity output)                353 non-null    object
#  20  Surface area (sq. km)                                                       353 non-null    float64
#  21  Unemployment, total (% of total labor force) (national estimate)            353 non-null    object
#  22  Total area (Square Km)                                                      351 non-null    float64
#  23  PM10_ConcentrationAvg                                                       336 non-null    float64
#  24  PM25_ConcentrationAvg                                                       339 non-null    float64
#  25  NO2_ConcentrationAvg                                                        328 non-null    float64
#  26  Greenhouse gases (Kg CO2-equivalent Per Person)                             275 non-null    float64
#  27  Sulphur oxides (tonnes)                                                     242 non-null    float64
#  28  Total sales of agricultural pesticides (tonnes)                             297 non-null    float64
#  29  Share of population who are daily smokers (Pct population)                  179 non-null    float64
#  30  u10                                                                         353 non-null    float64
#  31  v10                                                                         353 non-null    float64
#  32  d2m                                                                         353 non-null    float64
#  33  t2m                                                                         353 non-null    float64
#  34  sst                                                                         353 non-null    float64
#  35  sp                                                                          353 non-null    float64
#  36  skt                                                                         353 non-null    float64
#  37  blh                                                                         353 non-null    float64
# dtypes: float64(23), int64(3), object(12)
# memory usage: 104.9+ KB
#
# ======================================================================
#
# 📊 Statistiques descriptives:
# ======================================================================
#               Year         Value  Access to electricity (% of population)  \
# count   353.000000    353.000000                               353.000000
# mean   2016.657224   5978.411687                                99.112181
# std       2.792809   2627.473561                                 3.363675
# min    2010.000000   1867.314014                                76.300000
# 25%    2015.000000   3965.023538                               100.000000
# 50%    2017.000000   5338.870567                               100.000000
# 75%    2019.000000   7059.635546                               100.000000
# max    2021.000000  14323.418705                               100.000000
#
#        Compulsory education, duration (years)  GDP (current US$)  \
# count                              353.000000       3.530000e+02
# mean                                10.444759       1.587098e+12
# std                                  1.549535       3.795167e+12
# min                                  6.000000       1.006452e+10
# 25%                                  9.000000       7.055065e+10
# 50%                                 10.000000       3.552934e+11
# 75%                                 12.000000       1.276786e+12
# max                                 15.000000       2.368117e+13
#
#        GDP per capita (constant 2015 US$)  \
# count                          353.000000
# mean                         29770.097432
# std                          23570.751427
# min                           1235.159391
# 25%                          11839.245816
# 50%                          22738.490234
# 75%                          43898.771321
# max                         110873.185245
#
#        Life expectancy at birth, total (years)  \
# count                               353.000000
# mean                                 78.444187
# std                                   4.572119
# min                                  58.886000
# 25%                                  75.953659
# 50%                                  80.300000
# 75%                                  81.760976
# max                                  84.356341
#
#        Mortality rate, infant (per 1,000 live births)  Population, total  \
# count                                      353.000000       3.530000e+02
# mean                                         6.004249       1.019867e+08
# std                                          7.333610       2.908325e+08
# min                                          1.800000       5.069530e+05
# 25%                                          2.800000       5.111300e+06
# 50%                                          3.500000       1.047441e+07
# 75%                                          5.500000       5.378257e+07
# max                                         46.700000       1.411100e+09
#
#        Surface area (sq. km)  Total area (Square Km)  PM10_ConcentrationAvg  \
# count           3.530000e+02            3.510000e+02             336.000000
# mean            1.164862e+06            1.171745e+06              28.626772
# std             2.848806e+06            2.857949e+06              20.718049
# min             2.590000e+03            2.590000e+03              10.199808
# 25%             4.534000e+04            4.534000e+04              18.114476
# 50%             1.110000e+05            1.110000e+05              22.359534
# 75%             4.474201e+05            4.766720e+05              31.774013
# max             1.709825e+07            1.709825e+07             176.580500
#
#        PM25_ConcentrationAvg  NO2_ConcentrationAvg  \
# count             339.000000            328.000000
# mean               17.874373             18.860392
# std                15.372005             23.772214
# min                 4.223700              0.007188
# 25%                 9.960723             13.217844
# 50%                14.170000             17.416667
# 75%                19.121873             20.646027
# max               131.223750            428.807667
#
#        Greenhouse gases (Kg CO2-equivalent Per Person)  \
# count                                       275.000000
# mean                                          9.483436
# std                                           4.260727
# min                                           2.112755
# 25%                                           6.655495
# 50%                                           8.537099
# 75%                                          10.531455
# max                                          22.762010
#
#        Sulphur oxides (tonnes)  \
# count               242.000000
# mean                326.848530
# std                 723.526779
# min                   0.648335
# 25%                  13.020062
# 50%                  48.677660
# 75%                 218.268325
# max                4110.000000
#
#        Total sales of agricultural pesticides (tonnes)  \
# count                                       297.000000
# mean                                      32040.225178
# std                                       72971.423885
# min                                          47.877000
# 25%                                        2177.874000
# 50%                                        6310.835000
# 75%                                       26857.000000
# max                                      449997.000000
#
#        Share of population who are daily smokers (Pct population)         u10  \
# count                                         179.000000           353.000000
# mean                                           17.297765             1.749017
# std                                             5.334644             1.925085
# min                                             5.950000            -5.661883
# 25%                                            13.725000             0.164563
# 50%                                            17.000000             2.137683
# 75%                                            20.150000             3.145111
# max                                            32.600000             6.015550
#
#               v10         d2m         t2m         sst             sp  \
# count  353.000000  353.000000  353.000000  353.000000     353.000000
# mean     0.557815  280.200918  283.619356  243.510243  100543.311802
# std      0.776228    5.993547    6.559591   77.089077    1798.483756
# min     -1.691500  264.626540  268.818368    0.000000   91924.118071
# 25%     -0.000136  276.447871  279.250440  277.359092  100483.783191
# 50%      0.551211  279.535858  282.277236  280.867049  101038.253887
# 75%      1.185231  284.020236  287.765514  285.356812  101549.553667
# max      2.207883  296.509662  300.097350  295.762541  102407.990350
#
#               skt          blh
# count  353.000000   353.000000
# mean   284.163115   759.866014
# std      6.854703   142.068962
# min    267.702099   326.114264
# 25%    279.840053   710.828077
# 50%    282.612945   796.648898
# 75%    288.544441   840.219518
# max    300.964366  1003.213312

# %%
# Dimensions temporelles et géographiques
print("🌍 Couverture géographique et temporelle:")
print(f"{'='*70}")
print(f"Nombre de pays: {df['Country Name'].nunique()}")
print(f"Nombre d'années: {df['Year'].nunique()}")
print(f"Période: {df['Year'].min()} - {df['Year'].max()}")
print(f"\nDiseases: {df['Disease'].unique()}")
print(f"Measures: {df['Measure'].unique()}")
print(f"Metrics: {df['Metric'].unique()}")
# Out:
# 🌍 Couverture géographique et temporelle:
# ======================================================================
# Nombre de pays: 47
# Nombre d'années: 12
# Période: 2010 - 2021
#
# Diseases: ['Asthma']
# Measures: ['Prevalence']
# Metrics: ['Rate']

# %% [markdown]
# ## 4. Analyse des valeurs manquantes

# %%
# Analyse des valeurs manquantes
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    'Colonne': missing.index,
    'Valeurs manquantes': missing.values,
    'Pourcentage': missing_pct.values
})

# Filtrer uniquement les colonnes avec des valeurs manquantes
missing_df = missing_df[missing_df['Valeurs manquantes'] > 0].sort_values('Pourcentage', ascending=False)

print("⚠️ Valeurs manquantes par colonne:")
print(f"{'='*70}")
if len(missing_df) > 0:
    print(missing_df.to_string(index=False))
    print(f"\n📊 Total de valeurs manquantes: {df.isnull().sum().sum()}")
else:
    print("✅ Aucune valeur manquante détectée!")
# Out:
# ⚠️ Valeurs manquantes par colonne:
# ======================================================================
#                                                    Colonne  Valeurs manquantes  Pourcentage
# Share of population who are daily smokers (Pct population)                 174    49.291785
#                                    Sulphur oxides (tonnes)                 111    31.444759
#            Greenhouse gases (Kg CO2-equivalent Per Person)                  78    22.096317
#            Total sales of agricultural pesticides (tonnes)                  56    15.864023
#                                       NO2_ConcentrationAvg                  25     7.082153
#                                      PM10_ConcentrationAvg                  17     4.815864
#                                      PM25_ConcentrationAvg                  14     3.966006
#                                     Total area (Square Km)                   2     0.566572
#
# 📊 Total de valeurs manquantes: 477

# %%
# Visualisation des valeurs manquantes
if len(missing_df) > 0:
    top_missing = missing_df.head(15)
    
    plt.figure(figsize=(14, 6))
    plt.barh(top_missing['Colonne'], top_missing['Pourcentage'], color='coral')
    plt.xlabel('Pourcentage de valeurs manquantes (%)', fontsize=12)
    plt.title('Top 15 colonnes avec valeurs manquantes', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("✅ Pas de visualisation nécessaire (aucune valeur manquante)")

# %% [markdown]
# ## 5. Distribution de la variable cible (Value)

# %%
# Statistiques sur la variable cible
print("📊 Statistiques de la variable 'Value':")
print(f"{'='*70}")
print(f"Moyenne: {df['Value'].mean():.4f}")
print(f"Médiane: {df['Value'].median():.4f}")
print(f"Écart-type: {df['Value'].std():.4f}")
print(f"Min: {df['Value'].min():.4f}")
print(f"Max: {df['Value'].max():.4f}")
print(f"Quartile 25%: {df['Value'].quantile(0.25):.4f}")
print(f"Quartile 75%: {df['Value'].quantile(0.75):.4f}")

# Distribution
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Histogramme
axes[0].hist(df['Value'].dropna(), bins=50, edgecolor='black', alpha=0.7, color='steelblue')
axes[0].axvline(df['Value'].mean(), color='red', linestyle='--', linewidth=2, label=f'Moyenne: {df["Value"].mean():.2f}')
axes[0].axvline(df['Value'].median(), color='green', linestyle='--', linewidth=2, label=f'Médiane: {df["Value"].median():.2f}')
axes[0].set_xlabel('Value', fontsize=11)
axes[0].set_ylabel('Fréquence', fontsize=11)
axes[0].set_title('Distribution de Value (Histogramme)', fontsize=12, fontweight='bold')
axes[0].legend()
axes[0].grid(alpha=0.3)

# Box plot
axes[1].boxplot(df['Value'].dropna(), vert=True)
axes[1].set_ylabel('Value', fontsize=11)
axes[1].set_title('Distribution de Value (Box Plot)', fontsize=12, fontweight='bold')
axes[1].grid(alpha=0.3)

# Violin plot
axes[2].violinplot([df['Value'].dropna()], vert=True, showmeans=True, showmedians=True)
axes[2].set_ylabel('Value', fontsize=11)
axes[2].set_title('Distribution de Value (Violin Plot)', fontsize=12, fontweight='bold')
axes[2].grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 📊 Statistiques de la variable 'Value':
# ======================================================================
# Moyenne: 5978.4117
# Médiane: 5338.8706
# Écart-type: 2627.4736
# Min: 1867.3140
# Max: 14323.4187
# Quartile 25%: 3965.0235
# Quartile 75%: 7059.6355

# %% [markdown]
# ## 6. Évolution temporelle

# %%
# Évolution temporelle globale (moyenne par année)
yearly_stats = df.groupby('Year')['Value'].agg(['mean', 'median', 'std', 'count']).reset_index()

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Graphique 1: Moyenne et médiane
axes[0].plot(yearly_stats['Year'], yearly_stats['mean'], marker='o', linewidth=2.5, 
             markersize=7, label='Moyenne', color='steelblue')
axes[0].plot(yearly_stats['Year'], yearly_stats['median'], marker='s', linewidth=2.5, 
             markersize=7, label='Médiane', color='coral')
axes[0].fill_between(yearly_stats['Year'], 
                      yearly_stats['mean'] - yearly_stats['std'],
                      yearly_stats['mean'] + yearly_stats['std'],
                      alpha=0.2, color='steelblue', label='±1 écart-type')
axes[0].set_xlabel('Année', fontsize=12)
axes[0].set_ylabel('Value', fontsize=12)
axes[0].set_title(f'Évolution temporelle globale de {disease_name} (Moyenne ± Écart-type)', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=10)
axes[0].grid(alpha=0.3)

# Graphique 2: Nombre d'observations
axes[1].bar(yearly_stats['Year'], yearly_stats['count'], color='lightgreen', edgecolor='black', alpha=0.7)
axes[1].set_xlabel('Année', fontsize=12)
axes[1].set_ylabel('Nombre d\'observations', fontsize=12)
axes[1].set_title('Nombre d\'observations par année', fontsize=14, fontweight='bold')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# Analyse de la tendance
trend_change = yearly_stats['mean'].iloc[-1] - yearly_stats['mean'].iloc[0]
trend_pct = (trend_change / yearly_stats['mean'].iloc[0]) * 100

print(f"📈 Analyse de la tendance:")
print(f"{'='*70}")
print(f"Valeur initiale ({yearly_stats['Year'].iloc[0]}): {yearly_stats['mean'].iloc[0]:.4f}")
print(f"Valeur finale ({yearly_stats['Year'].iloc[-1]}): {yearly_stats['mean'].iloc[-1]:.4f}")
print(f"Changement: {trend_change:.4f} ({trend_pct:+.2f}%)")
if trend_change > 0:
    print("➡️ Tendance: AUGMENTATION")
else:
    print("➡️ Tendance: DIMINUTION")
# Out:
# 📈 Analyse de la tendance:
# ======================================================================
# Valeur initiale (2010): 6692.2666
# Valeur finale (2021): 6139.4843
# Changement: -552.7822 (-8.26%)
# ➡️ Tendance: DIMINUTION

# %%
# Afficher les pays avec des observations en 2011
countries_2011 = df[df['Year'] == 2011]['Country Name'].unique()

print("🌍 Pays avec observations en 2011:")
print(f"{'='*70}")
print(f"Nombre de pays: {len(countries_2011)}")
print(f"\nListe des pays:")
for i, country in enumerate(countries_2011, 1):
    print(f"{i}. {country}")
# Out:
# 🌍 Pays avec observations en 2011:
# ======================================================================
# Nombre de pays: 1
#
# Liste des pays:
# 1. United States of America

# %% [markdown]
# ## 7. Analyse géographique (Top/Bottom pays)

# %%
# Calculer la moyenne par pays
country_avg = df.groupby('Country Name')['Value'].mean().sort_values(ascending=False)

fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Top 15 pays (valeurs les plus élevées)
top_15 = country_avg.head(15)
axes[0].barh(range(len(top_15)), top_15.values, color='darkred', edgecolor='black')
axes[0].set_yticks(range(len(top_15)))
axes[0].set_yticklabels(top_15.index, fontsize=10)
axes[0].set_xlabel('Valeur moyenne', fontsize=12)
axes[0].set_title('Top 15 pays - Valeurs les plus élevées', fontsize=13, fontweight='bold')
axes[0].invert_yaxis()
axes[0].grid(axis='x', alpha=0.3)

# Bottom 15 pays (valeurs les plus faibles)
bottom_15 = country_avg.tail(15).sort_values(ascending=True)
axes[1].barh(range(len(bottom_15)), bottom_15.values, color='darkgreen', edgecolor='black')
axes[1].set_yticks(range(len(bottom_15)))
axes[1].set_yticklabels(bottom_15.index, fontsize=10)
axes[1].set_xlabel('Valeur moyenne', fontsize=12)
axes[1].set_title('Bottom 15 pays - Valeurs les plus faibles', fontsize=13, fontweight='bold')
axes[1].invert_yaxis()
axes[1].grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"🌍 Résumé géographique:")
print(f"{'='*70}")
print(f"Pays avec valeur la plus élevée: {country_avg.index[0]} ({country_avg.iloc[0]:.4f})")
print(f"Pays avec valeur la plus faible: {country_avg.index[-1]} ({country_avg.iloc[-1]:.4f})")
print(f"Ratio max/min: {country_avg.iloc[0] / country_avg.iloc[-1]:.2f}x")
# Out:
# 🌍 Résumé géographique:
# ======================================================================
# Pays avec valeur la plus élevée: New Zealand (14264.9717)
# Pays avec valeur la plus faible: Kazakhstan (1872.7530)
# Ratio max/min: 7.62x

# %% [markdown]
# ## 8. Évolution par pays (Top 10)

# %%
# Évolution temporelle des top 10 pays
top_10_countries = country_avg.head(10).index

plt.figure(figsize=(14, 8))

for country in top_10_countries:
    country_data = df[df['Country Name'] == country].sort_values('Year')
    plt.plot(country_data['Year'], country_data['Value'], 
             marker='o', linewidth=2, markersize=5, label=country, alpha=0.8)

plt.xlabel('Année', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.title('Évolution temporelle - Top 10 pays avec valeurs les plus élevées', fontsize=14, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Analyse des corrélations (Features numériques)

# %%
# Identifier les colonnes numériques
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Retirer les colonnes d'identification
id_cols = ['Year']
feature_cols = [col for col in numeric_cols if col not in id_cols]

print(f"📊 Colonnes numériques à analyser: {len(feature_cols)}")

# Calculer les corrélations avec Value
if 'Value' in feature_cols:
    all_corr = df.corr(numeric_only=True)['Value'].drop('Value')  # conserve les signes
    
    # Top 15 corrélations
    top_15_corr = all_corr.abs().sort_values(ascending=False).head(15)
    
    print(f"\n🔗 Top 15 features corrélées avec 'Value':")
    print(f"{'='*70}")
    for feat, corr in top_15_corr.items():
        print(f"{feat[:50]:50s} : {corr:.4f}")
    
    # Visualisation
    plt.figure(figsize=(12, 8))
    plt.barh(range(len(top_15_corr)), top_15_corr.values, color='teal', edgecolor='black')
    plt.yticks(range(len(top_15_corr)), [f[:40] for f in top_15_corr.index], fontsize=10)
    plt.xlabel('Corrélation absolue avec Value', fontsize=12)
    plt.title('Top 15 Features - Corrélation avec Value', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Colonne 'Value' non trouvée dans les données numériques")
# Out:
# 📊 Colonnes numériques à analyser: 25
#
# 🔗 Top 15 features corrélées avec 'Value':
# ======================================================================
# GDP per capita (constant 2015 US$)                 : 0.5669
# Life expectancy at birth, total (years)            : 0.5430
# PM25_ConcentrationAvg                              : 0.4690
# PM10_ConcentrationAvg                              : 0.4565
# Share of population who are daily smokers (Pct pop : 0.4258
# Greenhouse gases (Kg CO2-equivalent Per Person)    : 0.3675
# Mortality rate, infant (per 1,000 live births)     : 0.3443
# v10                                                : 0.3410
# Compulsory education, duration (years)             : 0.3117
# Access to electricity (% of population)            : 0.2810
# Population, total                                  : 0.2577
# skt                                                : 0.2237
# t2m                                                : 0.2198
# d2m                                                : 0.2169
# GDP (current US$)                                  : 0.2025

# %%
# Matrice de corrélation pour top features
if 'Value' in feature_cols and len(top_15_corr) > 0:
    # Sélectionner top features + Value
    selected_features = list(top_15_corr.head(10).index) + ['Value']
    
    # Calculer matrice de corrélation
    corr_matrix = df[selected_features].corr()
    
    # Heatmap
    plt.figure(figsize=(12, 10))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', center=0,
                square=True, linewidths=0.5, cbar_kws={"shrink": 0.8},
                xticklabels=[f[:30] for f in corr_matrix.columns],
                yticklabels=[f[:30] for f in corr_matrix.index])
    plt.title('Matrice de corrélation - Top 10 Features vs Value', fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, ha='right', fontsize=9)
    plt.yticks(fontsize=9)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 10. Distribution par année (Box plots)

# %%
# Box plots par année
years_list = sorted(df['Year'].unique())

plt.figure(figsize=(16, 6))

# Créer les données pour chaque année
data_by_year = [df[df['Year'] == year]['Value'].dropna().values for year in years_list]

# Box plot
bp = plt.boxplot(data_by_year, labels=years_list, patch_artist=True)

# Colorer les box plots
for patch in bp['boxes']:
    patch.set_facecolor('lightblue')
    patch.set_alpha(0.7)

plt.xlabel('Année', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.title('Distribution de Value par année', fontsize=14, fontweight='bold')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Scatter plots (Value vs Top Features)

# %%
# Scatter plots pour les 6 features les plus corrélées
if 'Value' in feature_cols and len(top_15_corr) > 0:
    top_6_features = top_15_corr.head(6).index
    
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    axes = axes.ravel()
    
    for idx, feature in enumerate(top_6_features):
        # Scatter plot
        axes[idx].scatter(df[feature], df['Value'], alpha=0.5, s=30, color='steelblue', edgecolors='black', linewidth=0.5)
        
        # Ligne de régression
        mask = df[[feature, 'Value']].notna().all(axis=1)
        if mask.sum() > 1:
            z = np.polyfit(df.loc[mask, feature], df.loc[mask, 'Value'], 1)
            p = np.poly1d(z)
            x_line = np.linspace(df[feature].min(), df[feature].max(), 100)
            axes[idx].plot(x_line, p(x_line), "r--", linewidth=2, label='Régression linéaire')
        
        axes[idx].set_xlabel(feature[:40], fontsize=10)
        axes[idx].set_ylabel('Value', fontsize=10)
        axes[idx].set_title(f'Value vs {feature[:30]}\n(corr: {all_corr[feature]:.3f})', 
                           fontsize=11, fontweight='bold')
        axes[idx].grid(alpha=0.3)
        axes[idx].legend(fontsize=8)
    
    plt.tight_layout()
    plt.show()
else:
    print("⚠️ Pas assez de features pour générer les scatter plots")

# %% [markdown]
# ## 12. Résumé de l'exploration

# %%
print("="*80)
print("📊 RÉSUMÉ DE L'EXPLORATION DES DONNÉES")
print("="*80)

print(f"\n📁 Fichier analysé: {file_name}")
print(f"📏 Dimensions: {df.shape[0]} lignes × {df.shape[1]} colonnes")

print(f"\n🌍 Couverture:")
print(f"   • Pays: {df['Country Name'].nunique()}")
print(f"   • Années: {df['Year'].nunique()} ({df['Year'].min()} - {df['Year'].max()})")

print(f"\n📊 Variable cible (Value):")
print(f"   • Moyenne: {df['Value'].mean():.4f}")
print(f"   • Médiane: {df['Value'].median():.4f}")
print(f"   • Min: {df['Value'].min():.4f}")
print(f"   • Max: {df['Value'].max():.4f}")

print(f"\n⚠️ Qualité des données:")
total_missing = df.isnull().sum().sum()
print(f"   • Valeurs manquantes totales: {total_missing}")
if total_missing > 0:
    print(f"   • Pourcentage: {(total_missing / (df.shape[0] * df.shape[1])) * 100:.2f}%")

if len(country_avg) > 0:
    print(f"\n🏆 Pays extrêmes:")
    print(f"   • Plus élevé: {country_avg.index[0]} ({country_avg.iloc[0]:.4f})")
    print(f"   • Plus faible: {country_avg.index[-1]} ({country_avg.iloc[-1]:.4f})")

if 'Value' in feature_cols and len(top_15_corr) > 0:
    print(f"\n🔗 Top 3 corrélations (abs) avec Value:")
    for i, (feat, corr) in enumerate(top_15_corr.head(3).items(), 1):
        print(f"   {i}. {feat[:50]}: {corr:.4f}")

print(f"\n📈 Tendance temporelle:")
if trend_change > 0:
    print(f"   • AUGMENTATION de {trend_pct:+.2f}% sur la période")
else:
    print(f"   • DIMINUTION de {trend_pct:.2f}% sur la période")

print("\n" + "="*80)
print("✅ Exploration terminée!")
print("="*80)
# Out:
# ================================================================================
# 📊 RÉSUMÉ DE L'EXPLORATION DES DONNÉES
# ================================================================================
#
# 📁 Fichier analysé: asthma_prevalence_rate.csv
# 📏 Dimensions: 353 lignes × 38 colonnes
#
# 🌍 Couverture:
#    • Pays: 47
#    • Années: 12 (2010 - 2021)
#
# 📊 Variable cible (Value):
#    • Moyenne: 5978.4117
#    • Médiane: 5338.8706
#    • Min: 1867.3140
#    • Max: 14323.4187
#
# ⚠️ Qualité des données:
#    • Valeurs manquantes totales: 477
#    • Pourcentage: 3.56%
#
# 🏆 Pays extrêmes:
#    • Plus élevé: New Zealand (14264.9717)
#    • Plus faible: Kazakhstan (1872.7530)
#
# 🔗 Top 3 corrélations (abs) avec Value:
#    1. GDP per capita (constant 2015 US$): 0.5669
#    2. Life expectancy at birth, total (years): 0.5430
#    3. PM25_ConcentrationAvg: 0.4690
#
# 📈 Tendance temporelle:
#    • DIMINUTION de -8.26% sur la période
#
# ================================================================================
# ✅ Exploration terminée!
# ================================================================================
